# %% [markdown]
# This block is setup and installations; the last function makes the text output wrap inside the window.

# %%
# !pip install munkres
# !pip install boto3
# !pip install ipyplot

from google.colab import drive
import os
import json
import numpy as np
from munkres import Munkres, make_cost_matrix
import copy
from IPython.display import HTML, display
import boto3
import sys
import shutil

drive.mount('/content/drive')
os.chdir("/content/drive/My Drive/BWC/Inter-reliability")
def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)
# Out:
# Collecting munkres
#   Downloading https://files.pythonhosted.org/packages/90/ab/0301c945a704218bc9435f0e3c88884f6b19ef234d8899fb47ce1ccfd0c9/munkres-1.1.4-py2.py3-none-any.whl
# Installing collected packages: munkres
# Successfully installed munkres-1.1.4
# Collecting boto3
#   Downloading https://files.pythonhosted.org/packages/62/b3/8c889dd3d5ae47a9c4468cc20ef980adc4a16f06f0937ab33f78b58b5eda/boto3-1.17.53-py2.py3-none-any.whl (131kB)
#      |████████████████████████████████| 133kB 11.1MB/s
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/00/89/0cb4e92c239e6425b9b0035227b8cdf9d3d098a5c9e95632c3815df63a09/s3transfer-0.3.7-py2.py3-none-any.whl (73kB)
#      |████████████████████████████████| 81kB 4.7MB/s
# Collecting botocore<1.21.0,>=1.20.53
#   Downloading https://files.pythonhosted.org/packages/92/4e/232e261b739534e216f28d935a06c44840221c3476ebcdb411cd0fc2bf16/botocore-1.20.53-py2.py3-none-any.whl (7.4MB)
#      |████████████████████████████████| 7.4MB 15.4MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.21.0,>=1.20.53->boto3) (2.8.1)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading https://files.pythonhosted.org/packages/09/c6/d3e3abe5b4f4f16cf0dfc9240ab7ce10c2baa0e268989a4e3ec19e90c84e/urllib3-1.26.4-py2.py3-none-any.whl (153kB)
#      |████████████████████████████████| 153kB 43.3MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.53->boto3) (1.15.0)
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.4 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, boto3
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed boto3-1.17.53 botocore-1.20.53 jmespath-0.10.0 s3transfer-0.3.7 urllib3-1.26.4
# Collecting ipyplot
#   Downloading https://files.pythonhosted.org/packages/c8/2d/ba3031b6945e40ac1137ffb3931528bf4a76f36f0668b6c1879fadac070d/ipyplot-1.1.0-py3-none-any.whl
# Collecting shortuuid
#   Downloading https://files.pythonhosted.org/packages/25/a6/2ecc1daa6a304e7f1b216f0896b26156b78e7c38e1211e9b798b4716c53d/shortuuid-1.0.1-py3-none-any.whl
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from ipyplot) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ipyplot) (1.19.5)
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/dist-packages (from ipyplot) (5.5.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (1.0.18)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (2.6.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (0.8.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (5.0.5)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (54.2.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from IPython->ipyplot) (4.4.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->ipyplot) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->ipyplot) (1.15.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from traitlets>=4.2->IPython->ipyplot) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect; sys_platform != "win32"->IPython->ipyplot) (0.7.0)
# Installing collected packages: shortuuid, ipyplot
# Successfully installed ipyplot-1.1.0 shortuuid-1.0.1
# Mounted at /content/drive

# %% [markdown]
# Choose filepaths from above and input into strings below.

# %%
filepath1 = '4-11 Results.json'
filepath2 = 'mar30_execute.json'

vid1 = {}
vid2 = {}

with open(filepath1) as f:
    file1 = json.load(f)

with open(filepath2) as f:
    file2 = json.load(f)

def get_iou(pred_box, gt_box):
    """
    pred_box : the coordinate for predict bounding box
    gt_box :   the coordinate for ground truth bounding box
    return :   the iou score
    the  left-down coordinate of  pred_box:(pred_box[0], pred_box[1])
    the  right-up coordinate of  pred_box:(pred_box[2], pred_box[3])
    """
    # 1.get the coordinate of intersection
    ixmin = max(pred_box[0], gt_box[0])
    ixmax = min(pred_box[2], gt_box[2])
    iymin = max(pred_box[1], gt_box[1])
    iymax = min(pred_box[3], gt_box[3])

    iw = np.maximum(ixmax-ixmin+1., 0.)
    ih = np.maximum(iymax-iymin+1., 0.)

    # 2. calculate the area of intersection
    inters = iw*ih

    # 3. calculate the area of union
    uni = ((pred_box[2]-pred_box[0]+1.) * (pred_box[3]-pred_box[1]+1.) +
           (gt_box[2] - gt_box[0] + 1.) * (gt_box[3] - gt_box[1] + 1.) -
           inters)

    # 4. calculate the overlaps between pred_box and gt_box
    iou = inters / uni

    return iou

#total labels
labels_dict = {} 
actions_dict = {}

for vid in range(len(file1)):
    vid1 = file1[vid]
    frame_list = vid1['data']['image_url']
    num_frames = len(frame_list)
    match = False
    for i in range(len(file2)):
      if file2[i]['data']['image_url'] == frame_list:
        vid2 = file2[i] #if there is no match the program breaks here
        match = True
    
    if not match:
      print('No match for video', vid)
      break
    
    #first loop goes through and sorts data by frame for each video
    vid1_dict = dict()
    vid2_dict = dict()

    if vid1['result']['data'] == '[]': #if there is no annotations
      print()
      print("Vid1", vid, '- no annotations')
      continue
        
    for i in vid1['result']['data']:
      if i['frame'] in vid1_dict:
        vid1_dict[i['frame']].append(i)
      else:
        vid1_dict[i['frame']] = [i]    

    if vid2['result']['data'] == '[]': #if there is no annotations
      print()
      print("Vid2", vid, '- no annotations')
      continue 

    for i in vid2['result']['data']:
      if i['frame'] in vid2_dict:
        vid2_dict[i['frame']].append(i)
      else:
        vid2_dict[i['frame']] = [i]
        
    TN = 0 #True Negatives
    TP = 0 #True Positives
    FP = 0 #False Positives
    FN = 0 #False Negatives
    IOU = {} #Key - Frame Number, Value - List of Computed IOU Scores from each Frame
    by_list1 = []
    by_list2 = []
    label_dict1 = {}
    action_dict1 = {}
    label_dict2 = {}
    action_dict2 = {}
    ann_1 = 0
    ann_2 = 0
    #Now iterates with vid1 as ground truth
    for i in range(num_frames): 
        #First gets the number of boxes on a given frame for both videos
        if i in vid1_dict.keys():
            num1 = len(vid1_dict[i])
        else:
            num1 = 0 
        if i in vid2_dict.keys():
            num2 = len(vid2_dict[i])
        else:
            num2 = 0

        #CASE 1 - Both Videos have no annotation on frame
        if num1 == num2 == 0:
            TN += 1
        #CASE 2 - Video 1 has no annotations
        elif num1 == 0:
            FP += num2
            ann_2 += num2
            for j in range(len(vid2_dict[i])):
                for label in vid2_dict[i][j]['label']:
                  if label in labels_dict:
                    labels_dict[label] += 1
                  else:
                    labels_dict[label] = 1
                  if label in label_dict2:
                    label_dict2[label] += 1
                  else:
                    label_dict2[label] = 1

                for labelAttrs in vid2_dict[i][j]['labelAttrs']:
                  if type(labelAttrs['value']) is list:
                    for value in labelAttrs['value']:    
                      if value in actions_dict:
                        actions_dict[value] += 1
                      else:
                        actions_dict[value] = 1
                      if value in action_dict2:
                        action_dict2[value] += 1
                      else:
                        action_dict2[value] = 1
                  else:
                    if labelAttrs['value'] in actions_dict:
                      actions_dict[labelAttrs['value']] += 1
                    else:
                      actions_dict[labelAttrs['value']] = 1
                    if labelAttrs['value'] in action_dict2:
                      action_dict2[labelAttrs['value']] += 1
                    else:
                      action_dict2[labelAttrs['value']] = 1

                by_list2.append(vid2_dict[i][j]['cBy'])

        #CASE 3 - Video 2 has no annotations
        elif num2 == 0:
            FN += num1
            ann_1 += num1
            for j in range(len(vid1_dict[i])):
                for label in vid1_dict[i][j]['label']:
                  if label in label_dict1:
                    labels_dict[label] += 1
                  else:
                    labels_dict[label] = 1

                  if label in label_dict1:
                    label_dict1[label] += 1
                  else:
                    label_dict1[label] = 1
              
                for labelAttrs in vid1_dict[i][j]['labelAttrs']:
                  if type(labelAttrs['value']) is list:
                    for value in labelAttrs['value']:    
                      if value in actions_dict:
                        actions_dict[value] += 1
                      else:
                        actions_dict[value] = 1                     
                      if value in action_dict1:
                        action_dict1[value] += 1
                      else:
                        action_dict1[value] = 1
                  else:
                    if labelAttrs['value'] in actions_dict:
                      actions_dict[labelAttrs['value']] += 1
                    else:
                      actions_dict[labelAttrs['value']] = 1
                    if labelAttrs['value'] in action_dict1:
                      action_dict1[labelAttrs['value']] += 1
                    else:
                      action_dict1[labelAttrs['value']] = 1
                
                by_list1.append(vid1_dict[i][j]['cBy'])

        #CASE 4 - Both videos have annotations
        else:
            ann_1 += num1
            ann_2 += num2
            n = max(len(vid1_dict[i]), len(vid2_dict[i]))
            matrix = [[0 for g in range(n)] for h in range(n)]
            for j in vid1_dict[i]: #ground truth
                for k in vid2_dict[i]: #predicted
                    matrix[vid1_dict[i].index(j)][vid2_dict[i].index(k)] = get_iou(
                        [j['coordinate'][0]['x'], j['coordinate'][0]['y'], j['coordinate'][2]['x'], j['coordinate'][2]['y']],
                        [k['coordinate'][0]['x'], k['coordinate'][0]['y'], k['coordinate'][2]['x'], k['coordinate'][2]['y']])
            cost_matrix = make_cost_matrix(matrix, lambda x : 1 - x)
            m = Munkres()
            indexes = m.compute(cost_matrix)
            for row, column in indexes:
                if matrix[row][column] == 0:
                    #CASE 1 - Match is 0 between actual bounding boxes - not dummy rows/columns
                    #means that both P and GT each had bounding boxes that did not overlap
                    if row < num1 and column < num2 and vid1_dict!=vid2_dict:
                        FP += 1
                        FN += 1
                    #CASE 2 - Match is between an actual box in the GT and a dummy column in predicted
                    elif column >= num2:
                        FN += 1
                    #CASE 3 - Match is between an actual box in the predicted and a dummy row in GT
                    elif row >= num1:
                        FP += 1
                else:
                    TP += 1
                    if i not in IOU.keys():
                        IOU[i] = [matrix[row][column]]
                    else:
                        IOU[i].append(matrix[row][column])       
            
            for j in range(len(vid1_dict[i])):
                for label in vid1_dict[i][j]['label']:
                  if label in labels_dict:
                    labels_dict[label] += 1
                  else:
                    labels_dict[label] = 1

                  if label in label_dict1:
                    label_dict1[label] += 1
                  else:
                    label_dict1[label] = 1
              
                for labelAttrs in vid1_dict[i][j]['labelAttrs']:
                  if type(labelAttrs['value']) is list:
                    for value in labelAttrs['value']:    
                      if value in actions_dict:
                        actions_dict[value] += 1
                      else:
                        actions_dict[value] = 1                     
                      if value in action_dict1:
                        action_dict1[value] += 1
                      else:
                        action_dict1[value] = 1
                  else:
                    if labelAttrs['value'] in actions_dict:
                      actions_dict[labelAttrs['value']] += 1
                    else:
                      actions_dict[labelAttrs['value']] = 1
                    if labelAttrs['value'] in action_dict1:
                      action_dict1[labelAttrs['value']] += 1
                    else:
                      action_dict1[labelAttrs['value']] = 1
                
                by_list1.append(vid1_dict[i][j]['cBy'])

            for j in range(len(vid2_dict[i])):
                for label in vid2_dict[i][j]['label']:
                  if label in labels_dict:
                    labels_dict[label] += 1
                  else:
                    labels_dict[label] = 1
                  if label in label_dict2:
                    label_dict2[label] += 1
                  else:
                    label_dict2[label] = 1

                for labelAttrs in vid2_dict[i][j]['labelAttrs']:
                  if type(labelAttrs['value']) is list:
                    for value in labelAttrs['value']:    
                      if value in actions_dict:
                        actions_dict[value] += 1
                      else:
                        actions_dict[value] = 1
                      if value in action_dict2:
                        action_dict2[value] += 1
                      else:
                        action_dict2[value] = 1
                  else:
                    if labelAttrs['value'] in actions_dict:
                      actions_dict[labelAttrs['value']] += 1
                    else:
                      actions_dict[labelAttrs['value']] = 1
                    if labelAttrs['value'] in action_dict2:
                      action_dict2[labelAttrs['value']] += 1
                    else:
                      action_dict2[labelAttrs['value']] = 1

                by_list2.append(vid2_dict[i][j]['cBy'])
    
    print(' ')
    print("Video #", vid)
    print('FN: ', FN)
    print('FP: ', FP)
    print('TN: ', TN)

    mean_IOU = 0
    total_IOU = 0
    num_matches = 0
    for k, v in IOU.items():
      for i in v:
        total_IOU += i
        num_matches += 1
    if num_matches == 0:
      mean_IOU = 0
    else:
      mean_IOU = total_IOU/num_matches
    if mean_IOU != 1.0:
      #print('IOU: ', IOU)
      pass
    print('avg IOU', mean_IOU)
    print('total IOU', total_IOU)
    print('Total Matches', num_matches)
    if FP + TP !=0:
      print('Precision', TP/(FP+TP))
    print('Recall', TP/(TP+FN))
    print('Number of Boxes for 1st', ann_1)
    print('Authors of 1st', list(set(by_list1)))
    print('Labels of 1st', dict(sorted(label_dict1.items(), key=lambda item: item[1], reverse = True)))
    print('Actions of 1st:', dict(sorted(action_dict1.items(), key=lambda item: item[1], reverse = True)))
    print('Number of Boxes for 2nd', ann_2)
    print('Authors of 2nd', list(set(by_list2)))
    print('Labels of 2st', dict(sorted(label_dict2.items(), key=lambda item: item[1], reverse = True)))
    print('Actions of 2st:', dict(sorted(action_dict2.items(), key=lambda item: item[1], reverse = True)))

print()
print(labels_dict)
print()
print(dict(sorted(actions_dict.items(), key=lambda item: item[1], reverse = True)))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#
# Video # 0
# FN:  0
# FP:  305
# TN:  300
# avg IOU 0.485830189702455
# total IOU 44.210547262923406
# Total Matches 91
# Precision 0.2297979797979798
# Recall 1.0
# Number of Boxes for 1st 91
# Authors of 1st ['0', '16736']
# Labels of 1st {'Police Officer': 51, 'First Person POV': 32, 'Civilian': 8}
# Actions of 1st: {'': 106, 'Has firearm': 74, 'Male': 53, 'Uniform': 51, 'White': 48, 'Drawing a weapon': 31, 'Standing': 26, 'Holding person': 21, 'Entering door/building': 20, 'Has taser': 15, 'Lying on ground': 10, 'Searching (search of a place or space)': 9, 'Sitting/Kneeling/Crouching on ground': 7, 'Unable to tell': 6, 'Walking away': 5, 'Raising hands': 4, 'Holstering a weapon': 3, 'Handcuffing': 3, 'Reaching for weapon': 2, 'Unable to determine': 1}
# Number of Boxes for 2nd 396
# Authors of 2nd ['16727', '0', '16734']
# Labels of 2st {'Police Officer': 288, 'First Person POV': 66, 'Civilian': 41}
# Actions of 2st: {'Male': 347, 'Standing': 305, 'Uniform': 297, '': 245, 'White': 126, 'Questioning/Talking to': 97, 'Has firearm': 61, "Can't tell": 55, 'Entering door/building': 44, 'Unable to determine': 37, 'Lying on ground': 33, 'Holding person': 28, 'Unable to tell': 27, 'Sitting/Kneeling/Crouching on ground': 24, 'Searching (search of a place or space)': 24, 'Mentally Distressed/Confused': 16, 'Showing aggression': 13, 'Walking towards': 10, 'Female': 7, 'Walking away': 6, 'Frisking (search of a person)': 5, 'Holstering a weapon': 4, 'Drawing a weapon': 4, 'Raising hands': 3, 'Black or African American': 3, 'Sitting': 2, 'Kneeling on person': 2, 'Entering a police vehicle': 1}
#
# Video # 1
# FN:  5
# FP:  28
# TN:  61
# avg IOU 0.41159286660649297
# total IOU 6.1738929990973945
# Total Matches 15
# Precision 0.3488372093023256
# Recall 0.75
# Number of Boxes for 1st 20
# Authors of 1st ['0', '16736']
# Labels of 1st {'Civilian': 16, 'Police Officer': 4}
# Actions of 1st: {'': 24, 'Lying on ground': 16, 'Male': 8, 'White': 4, 'Uniform': 4, 'Sitting/Kneeling/Crouching on ground': 3, 'Holding person': 3, 'Black or African American': 2, 'Unable to tell': 2, 'Raising hands': 1, 'Standing': 1, 'Injured': 1}
# Number of Boxes for 2nd 43
# Authors of 2nd ['16738', '0']
# Labels of 2st {'Police Officer': 37, 'Civilian': 6}
# Actions of 2st: {'Unable to tell': 38, 'Standing': 33, 'Unable to determine': 26, 'Uniform': 20, 'Searching (search of a place or space)': 19, 'Male': 17, "Can't tell": 17, 'Lying on ground': 6, 'Sitting/Kneeling/Crouching on ground': 4, 'Black or African American': 2, 'Frisking (search of a person)': 2, 'Two or more': 2, 'White': 1, 'Holding person': 1, 'Holstering a weapon': 1}
#
# Video # 2
# FN:  0
# FP:  94
# TN:  51
# avg IOU 0.5544005683473547
# total IOU 8.316008525210322
# Total Matches 15
# Precision 0.13761467889908258
# Recall 1.0
# Number of Boxes for 1st 15
# Authors of 1st ['16736']
# Labels of 1st {'Civilian': 12, 'Police Officer': 3}
# Actions of 1st: {'': 24, 'Lying on ground': 12, 'Holding person': 3, 'Has firearm': 3, 'Unable to tell': 3, 'Uniform': 3, 'Handcuffing': 2, 'Female': 2, 'Male': 1}
# Number of Boxes for 2nd 109
# Authors of 2nd ['16732', '16725', '0']
# Labels of 2st {'Police Officer': 71, 'Civilian': 32, 'First Person POV': 6}
# Actions of 2st: {'Male': 61, 'Standing': 56, 'Unable to tell': 53, 'Uniform': 53, 'White': 43, 'Unable to determine': 35, 'Lying on ground': 32, '': 32, 'Intoxicated': 25, 'Mentally Distressed/Confused': 25, "Can't tell": 18, 'Searching (search of a place or space)': 9, 'Has firearm': 5, 'Handcuffing': 5, 'Showing aggression': 4, 'Shoving/pushing': 4, 'Walking towards': 3, 'Running towards': 2, 'Frisking (search of person)': 2, 'Yelling/Gesticulating': 2, 'Holding person': 2, 'Walking away': 2, 'Questioning/Talking to': 2, 'Sitting/Kneeling/Crouching on ground': 1, 'Kneeling on': 1, 'Searching (search of place or space)': 1}
#
# Video # 3
# FN:  2
# FP:  75
# TN:  54
# avg IOU 0.59675871992882
# total IOU 11.33841567864758
# Total Matches 19
# Precision 0.20212765957446807
# Recall 0.9047619047619048
# Number of Boxes for 1st 21
# Authors of 1st ['0', '16736']
# Labels of 1st {'Civilian': 15, 'Police Officer': 6}
# Actions of 1st: {'Male': 16, 'Lying on ground': 15, 'White': 13, '': 10, 'Injured': 10, 'Uniform': 6, 'Standing': 5, 'Unable to tell': 3, 'Has firearm': 1, 'Sitting/Kneeling/Crouching on ground': 1}
# Number of Boxes for 2nd 94
# Authors of 2nd ['16737']
# Labels of 2st {'Police Officer': 75, 'Civilian': 19}
# Actions of 2st: {'Standing': 71, 'Uniform': 71, 'Male': 59, 'White': 53, 'Unable to tell': 41, 'Unable to determine': 35, 'Lying on ground': 19, 'Injured': 18, 'Walking towards': 5, "Can't tell": 4, 'Sitting/Kneeling/Crouching on ground': 1}
#
# Video # 4
# FN:  612
# FP:  25
# TN:  42
# avg IOU 0.6975782562612242
# total IOU 691.3000519548732
# Total Matches 991
# Precision 0.9753937007874016
# Recall 0.6182158452900811
# Number of Boxes for 1st 1603
# Authors of 1st ['16730', '0']
# Labels of 1st {'Police Officer': 973, 'Civilian': 465, 'Ambulance': 102, 'First Person POV': 39, 'Bystander': 13, 'Police Vehicle': 10}
# Actions of 1st: {'Uniform': 874, 'Standing': 825, 'Unable to tell': 724, 'Unable to determine': 620, 'Questioning/Talking to': 493, 'Female': 469, 'Male': 388, 'White': 373, 'Black or African American': 361, "Can't tell": 138, 'Parked': 112, 'Walking away': 98, 'Walking towards': 49, 'Sitting': 34, 'Has firearm': 26, 'Hispanic or Latino': 19, 'Sitting/Kneeling/Crouching on ground': 13, 'Lights flashing': 7, 'Exiting a vehicle': 3, '': 3, 'Injured': 3, 'Running away': 1}
# Number of Boxes for 2nd 1016
# Authors of 2nd ['16738', '16725', '0', '16728']
# Labels of 2st {'Police Officer': 625, 'Civilian': 298, 'Ambulance': 63, 'Police Vehicle': 12, 'First Person POV': 9}
# Actions of 2st: {'Uniform': 535, 'Female': 519, 'Standing': 451, 'Questioning/Talking to': 425, 'Black or African American': 312, '': 275, 'White': 275, 'Holstering a weapon': 267, 'Male': 244, 'Unable to tell': 237, 'Unable to determine': 75, 'Parked': 72, 'Walking away': 54, 'Walking towards': 50, 'Has firearm': 29, 'Leaving scene': 25, 'Hispanic or Latino': 14, "Can't tell": 12, 'Lights flashing': 5, 'Injured': 5, 'Sitting': 3, 'Exiting a vehicle': 3, 'Moving': 2, 'Running towards': 2, 'Holding person': 1}
#
# Video # 5
# FN:  9
# FP:  42
# TN:  19
# avg IOU 0.5608318587847476
# total IOU 227.1369028078228
# Total Matches 405
# Precision 0.9060402684563759
# Recall 0.9782608695652174
# Number of Boxes for 1st 414
# Authors of 1st ['16725', '16736']
# Labels of 1st {'Police Officer': 187, 'Civilian': 119, 'Ambulance': 73, 'Police Vehicle': 33, 'First Person POV': 2}
# Actions of 1st: {'Uniform': 187, 'Questioning/Talking to': 172, 'Female': 170, 'Standing': 141, 'Black or African American': 126, 'Male': 116, 'White': 114, 'Parked': 106, 'Unable to tell': 52, '': 29, 'Walking away': 26, 'Walking towards': 19, 'Lights flashing': 16, 'Unable to determine': 11, 'Leaving scene': 4, 'Exiting a vehicle': 2, 'Putting on PPE (e.g. gloves)': 2, 'Reaching for weapon': 2, 'Yelling/Gesticulating': 1}
# Number of Boxes for 2nd 447
# Authors of 2nd ['16731', '0', '16736', '16735']
# Labels of 2st {'Police Officer': 213, 'Civilian': 120, 'Ambulance': 76, 'Police Vehicle': 35, 'First Person POV': 3}
# Actions of 2st: {'Uniform': 207, 'Has firearm': 187, 'Female': 186, 'Questioning/Talking to': 181, 'Standing': 162, 'Black or African American': 139, 'White': 122, 'Male': 118, 'Parked': 111, 'Unable to tell': 75, 'Walking away': 35, 'Lights flashing': 31, 'Unable to determine': 30, 'Walking towards': 17, "Can't tell": 9, 'Leaving scene': 8, '': 2, 'Putting on PPE (e.g. gloves)': 2, 'Reaching for weapon': 2, 'Exiting a vehicle': 1, 'Yelling/Gesticulating': 1}
#
# Video # 6
# FN:  49
# FP:  137
# TN:  122
# avg IOU 0.6404433656787321
# total IOU 85.8194110009501
# Total Matches 134
# Precision 0.4944649446494465
# Recall 0.73224043715847
# Number of Boxes for 1st 183
# Authors of 1st ['16725', '16736']
# Labels of 1st {'Police Officer': 124, 'Civilian': 30, 'Police Vehicle': 21, 'First Person POV': 8}
# Actions of 1st: {'Uniform': 120, 'Male': 108, 'Standing': 84, 'White': 78, '': 61, 'Unable to determine': 44, 'Unable to tell': 36, 'Lying on ground': 30, 'Injured': 30, 'Questioning/Talking to': 27, 'Has firearm': 20, 'Drawing a weapon': 17, 'Parked': 15, 'Lights flashing': 14, 'Walking towards': 7, 'Moving': 6, 'Female': 6, 'Walking away': 3, 'Has taser': 2, 'Reaching for weapon': 2, "Can't tell": 2, 'Running towards': 1, 'Sitting/Kneeling/Crouching on ground': 1, 'Civilian Clothing': 1}
# Number of Boxes for 2nd 271
# Authors of 2nd ['16731', '0']
# Labels of 2st {'Police Officer': 203, 'Police Vehicle': 52, 'Civilian': 7}
# Actions of 2st: {'Standing': 207, 'Uniform': 203, 'Unable to tell': 196, 'Male': 185, 'Lights flashing': 52, 'Parked': 43, 'Unable to determine': 25, '': 21, 'Walking towards': 15, 'Moving': 10, 'White': 10, 'Lying on ground': 7, 'Intoxicated': 6, 'Injured': 6, 'Mentally Distressed/Confused': 6, 'Holstering a weapon': 5, 'Running towards': 5, 'Female': 5, "Can't tell": 3, 'Sitting/Kneeling/Crouching on ground': 2, 'Handcuffing': 2, 'Questioning/Talking to': 2, 'Civilian Clothing': 2}
#
# Video # 7
# FN:  30
# FP:  694
# TN:  103
# avg IOU 0.6407154472888744
# total IOU 148.00526832372998
# Total Matches 231
# Precision 0.24972972972972973
# Recall 0.8850574712643678
# Number of Boxes for 1st 261
# Authors of 1st ['16725']
# Labels of 1st {'Police Officer': 201, 'First Person POV': 22, 'Civilian': 20, 'Police Vehicle': 18}
# Actions of 1st: {'Male': 232, 'Uniform': 210, 'Standing': 143, 'White': 136, '': 84, 'Black or African American': 47, 'Holding person': 41, 'Has firearm': 29, 'Lying on ground': 20, 'Running away': 19, 'Sitting/Kneeling/Crouching on ground': 19, 'Parked': 18, 'Has taser': 16, 'Walking towards': 16, 'Lights flashing': 14, 'Injured': 11, 'Drawing a weapon': 10, 'Walking away': 10, 'Running towards': 7, 'Frisking (search of person)': 6, 'Handcuffing': 4, 'Leaving scene': 3, 'Exiting a vehicle': 2, 'Frisking (search of a person)': 2}
# Number of Boxes for 2nd 925
# Authors of 2nd ['16725', '16731', '0']
# Labels of 2st {'Police Officer': 515, 'Police Vehicle': 241, 'First Person POV': 76, 'Civilian': 26}
# Actions of 2st: {'Uniform': 480, 'Standing': 399, 'Male': 390, '': 389, 'White': 263, 'Parked': 253, 'Unable to tell': 231, 'Lights flashing': 202, 'Walking away': 128, 'Female': 117, 'Running towards': 72, 'Unable to determine': 42, 'Sitting/Kneeling/Crouching on ground': 41, 'Walking towards': 27, 'Holding person': 26, "Can't tell": 25, 'Handcuffing': 23, 'Lying on ground': 20, 'Black or African American': 20, 'Has firearm': 18, 'Frisking (search of a person)': 10, 'Kneeling on person': 10, 'Leaving scene': 10, 'Drawing a weapon': 9, 'Kneeling on': 6, 'Frisking (search of person)': 6, 'Exiting a vehicle': 2, 'Shoving/pushing': 1}
#
# Video # 8
# FN:  25
# FP:  112
# TN:  121
# avg IOU 0.5763616803231423
# total IOU 197.11569467051464
# Total Matches 342
# Precision 0.7533039647577092
# Recall 0.9318801089918256
# Number of Boxes for 1st 367
# Authors of 1st ['16731', '16736']
# Labels of 1st {'Police Officer': 276, 'Civilian': 71, 'First Person POV': 20}
# Actions of 1st: {'Unable to tell': 323, 'Uniform': 260, 'Male': 207, 'Standing': 194, 'Unable to determine': 135, 'Sitting/Kneeling/Crouching on ground': 98, 'Lying on ground': 71, 'Black or African American': 41, "Can't tell": 35, 'Female': 22, 'Has firearm': 18, 'Drawing a weapon': 17, 'Holding person': 10, '': 7, 'Injured': 5, 'Walking away': 3, 'Handcuffing': 2, 'Frisking (search of a person)': 2, 'Reloading firearm': 1, 'Kneeling on person': 1}
# Number of Boxes for 2nd 454
# Authors of 2nd ['16727', '16731', '0', '16737']
# Labels of 2st {'Police Officer': 359, 'Civilian': 75, 'First Person POV': 20}
# Actions of 2st: {'Unable to tell': 417, 'Unable to determine': 406, 'Standing': 263, "Can't tell": 196, 'Uniform': 178, 'Sitting/Kneeling/Crouching on ground': 100, 'Lying on ground': 72, 'Male': 41, 'Has firearm': 29, 'Injured': 20, 'White': 19, 'Black or African American': 14, 'Walking away': 13, '': 9, 'Holding person': 6, 'Wrestling/grappling': 5, 'Putting on PPE (e.g. gloves)': 3, 'Civilian Clothing': 3, 'Female': 3, 'Sitting': 1, 'Walking towards': 1, 'Other': 1}
#
# Video # 9
# FN:  42
# FP:  113
# TN:  115
# avg IOU 0.5526583592940638
# total IOU 138.71724818281
# Total Matches 251
# Precision 0.6895604395604396
# Recall 0.856655290102389
# Number of Boxes for 1st 293
# Authors of 1st ['16725']
# Labels of 1st {'Police Officer': 235, 'Civilian': 54, 'First Person POV': 4}
# Actions of 1st: {'': 238, 'Male': 195, 'Standing': 191, 'Uniform': 180, 'White': 58, 'Native Hawaiian or Other Pacific Islander': 58, 'Female': 57, 'Lying on ground': 54, 'Injured': 54, 'Sitting/Kneeling/Crouching on ground': 42, "Can't tell": 28, 'Black or African American': 10, 'Has firearm': 4, 'Putting on PPE (e.g. gloves)': 3, 'Holding person': 3, 'Kneeling on person': 2, 'Drawing a weapon': 1, 'Unable to tell': 1}
# Number of Boxes for 2nd 364
# Authors of 2nd ['16731', '0', '16734']
# Labels of 2st {'Police Officer': 263, 'Civilian': 55, 'First Person POV': 2, 'Police Vehicle': 1}
# Actions of 2st: {'': 574, 'Standing': 232, 'Male': 138, 'Uniform': 136, 'Sitting/Kneeling/Crouching on ground': 78, 'Unable to tell': 65, 'Lying on ground': 57, 'White': 35, 'Injured': 22, 'Female': 11, 'Frisking (search of a person)': 8, 'Unable to determine': 7, 'Exiting door/building': 4, 'Holding person': 4, 'Handcuffing': 3, 'Putting on PPE (e.g. gloves)': 2, 'Black or African American': 2, 'Walking away': 1, 'Parked': 1, 'Lights flashing': 1}
#
# Video # 10
# FN:  144
# FP:  44
# TN:  102
# avg IOU 0.6192208468115995
# total IOU 238.4000260224658
# Total Matches 385
# Precision 0.8974358974358975
# Recall 0.7277882797731569
# Number of Boxes for 1st 529
# Authors of 1st ['16731']
# Labels of 1st {'Police Officer': 303, 'Civilian': 188, 'First Person POV': 38}
# Actions of 1st: {'Unable to tell': 317, 'Male': 273, 'Standing': 244, 'Unable to determine': 239, 'Lying on ground': 183, "Can't tell": 168, 'Uniform': 161, 'Black or African American': 160, 'Injured': 119, 'Holding person': 103, 'Sitting/Kneeling/Crouching on ground': 85, '': 40, 'White': 38, 'Pulling away': 13, 'Mentally Distressed/Confused': 5, 'Female': 3, 'Running away': 2, 'Handcuffing': 1}
# Number of Boxes for 2nd 429
# Authors of 2nd ['16727', '0', '16734', '16737']
# Labels of 2st {'Police Officer': 248, 'Civilian': 171, 'First Person POV': 10}
# Actions of 2st: {'Male': 327, 'Uniform': 206, 'Black or African American': 190, 'Lying on ground': 161, 'Standing': 157, '': 117, 'Injured': 111, 'Unable to tell': 98, 'Unable to determine': 86, 'Sitting/Kneeling/Crouching on ground': 84, "Can't tell": 47, 'White': 35, 'Searching (search of a place or space)': 29, 'Holding person': 21, 'Has firearm': 16, 'Wrestling/Grappling': 11, 'Putting on PPE (e.g. gloves)': 11, 'Walking towards': 9, 'Frisking (search of a person)': 8, 'Other': 8, 'Walking away': 6, 'Mentally Distressed/Confused': 5, 'Defending (self)': 4, 'Female': 2, 'Kneeling on person': 1, 'Handcuffing': 1}
#
# Video # 11
# FN:  83
# FP:  67
# TN:  105
# avg IOU 0.5368729625775801
# total IOU 244.81407093537655
# Total Matches 456
# Precision 0.8718929254302104
# Recall 0.8460111317254174
# Number of Boxes for 1st 539
# Authors of 1st ['16725']
# Labels of 1st {'Police Officer': 245, 'Civilian': 196, 'First Person POV': 98}
# Actions of 1st: {'': 632, 'Male': 415, 'Standing': 230, 'Uniform': 210, 'Lying on ground': 196, 'Injured': 192, 'White': 132, 'Holding person': 57, 'Frisking (search of person)': 48, "Can't tell": 30, 'Sitting/Kneeling/Crouching on ground': 25, 'Has knife': 15, 'Kneeling on': 11, 'Has firearm': 2, 'Drawing a weapon': 2, 'Civilian Clothing': 2}
# Number of Boxes for 2nd 523
# Authors of 2nd ['16727', '16731', '0']
# Labels of 2st {'Police Officer': 246, 'Civilian': 191, 'First Person POV': 86}
# Actions of 2st: {'Unable to tell': 292, 'Unable to determine': 260, 'Male': 255, "Can't tell": 192, 'Standing': 191, 'Lying on ground': 189, 'Uniform': 142, 'White': 136, 'Black or African American': 94, 'Injured': 43, 'Sitting/Kneeling/Crouching on ground': 41, 'Holding person': 20, 'Walking towards': 10, 'Walking away': 8, '': 8, 'Frisking (search of a person)': 6, 'Frisking (search of person)': 5, 'Drawing a weapon': 4, 'Has firearm': 2, 'Sitting': 1, 'Has knife': 1, 'Asian': 1}
#
# Video # 12
# FN:  66
# FP:  136
# TN:  85
# avg IOU 0.6422706905756064
# total IOU 163.77902609677963
# Total Matches 255
# Precision 0.6521739130434783
# Recall 0.794392523364486
# Number of Boxes for 1st 321
# Authors of 1st ['16731', '0']
# Labels of 1st {'Police Officer': 309, 'Civilian': 12}
# Actions of 1st: {'Unable to tell': 321, 'Standing': 298, 'Uniform': 248, 'Male': 221, 'Unable to determine': 93, "Can't tell": 61, 'Sitting/Kneeling/Crouching on ground': 19, 'Lying on ground': 12, 'Female': 7, 'Running away': 2, 'Walking away': 1}
# Number of Boxes for 2nd 391
# Authors of 2nd ['16731', '0', '16728']
# Labels of 2st {'Police Officer': 375, 'Civilian': 16}
# Actions of 2st: {'Unable to tell': 366, 'Uniform': 359, 'Standing': 309, 'Unable to determine': 230, 'Male': 134, '': 59, 'Sitting/Kneeling/Crouching on ground': 31, 'Lying on ground': 16, 'Running away': 11, 'Walking towards': 9, "Can't tell": 7, 'Female': 2, 'Walking away': 2}
#
# Video # 13
# FN:  7
# FP:  344
# TN:  124
# avg IOU 0.5789606806488417
# total IOU 339.8499195408701
# Total Matches 587
# Precision 0.6305048335123523
# Recall 0.9882154882154882
# Number of Boxes for 1st 594
# Authors of 1st ['16731', '0']
# Labels of 1st {'Civilian': 399, 'Police Officer': 177, 'Bystander': 10, 'First Person POV': 6, 'Police Vehicle': 1}
# Actions of 1st: {'Male': 557, 'Black or African American': 389, 'Sitting/Kneeling/Crouching on ground': 223, 'Unable to tell': 191, 'Uniform': 175, 'Questioning/Talking to': 164, 'Standing': 146, 'Holding person': 127, 'Walking away': 51, 'Unable to determine': 23, 'Lying on ground': 21, '': 6, "Can't tell": 6, 'Wrestling/Grappling': 5, 'Running away': 4, 'Shoving/pushing': 3, 'Throwing': 3, 'Pulling away': 2, 'Wrestling/grappling': 1, 'Kneeling on person': 1, 'Parked': 1, 'Lights flashing': 1}
# Number of Boxes for 2nd 931
# Authors of 2nd ['16737']
# Labels of 2st {'Civilian': 590, 'Police Officer': 244, 'First Person POV': 58, 'Police Vehicle': 39}
# Actions of 2st: {'Unable to tell': 687, 'Male': 496, 'Unable to determine': 394, 'Sitting/Kneeling/Crouching on ground': 331, 'Holding person': 250, 'Standing': 176, 'Black or African American': 172, "Can't tell": 159, 'Uniform': 144, 'Walking away': 124, 'Parked': 28, 'Lying on ground': 27, 'Lights flashing': 23, 'White': 13, 'Moving': 11, '': 11, 'Hispanic or Latino': 9, 'Walking towards': 7, 'Running away': 6, 'Kneeling on person': 3, 'Shoving/pushing': 2, 'Female': 2, 'Wrestling/grappling': 1, 'Has firearm': 1}
#
# Video # 14
# FN:  585
# FP:  282
# TN:  114
# avg IOU 0.5580370718888957
# total IOU 614.956853221563
# Total Matches 1102
# Precision 0.796242774566474
# Recall 0.6532305868405454
# Number of Boxes for 1st 1687
# Authors of 1st ['16731']
# Labels of 1st {'Police Officer': 1493, 'Bystander': 80, 'Police Vehicle': 65, 'Civilian': 31, 'Ambulance': 10, 'First Person POV': 8}
# Actions of 1st: {'Uniform': 1487, 'Male': 1197, 'Standing': 1096, 'White': 953, 'Unable to tell': 462, 'Sitting/Kneeling/Crouching on ground': 362, 'Holding person': 258, 'Female': 239, 'Injured': 134, 'Black or African American': 94, 'Unable to determine': 76, 'Wrestling/Grappling': 75, 'Parked': 74, 'Kneeling on person': 71, '': 49, 'Lying on ground': 26, 'Walking away': 20, 'Walking towards': 19, 'Yelling/Gesticulating': 14, "Can't tell": 8, 'Putting on PPE (e.g. gloves)': 5, 'Questioning/Talking to': 1}
# Number of Boxes for 2nd 1384
# Authors of 2nd ['16725', '16727', '16731']
# Labels of 2st {'Police Officer': 1234, 'Police Vehicle': 92, 'Civilian': 35, 'First Person POV': 13, 'Ambulance': 8, '': 2}
# Actions of 2st: {'Uniform': 1200, 'Male': 890, 'Standing': 885, 'White': 686, 'Unable to tell': 466, 'Sitting/Kneeling/Crouching on ground': 229, 'Has firearm': 219, 'Female': 196, 'Unable to determine': 194, 'Black or African American': 128, 'Parked': 93, 'Holding person': 91, 'Walking towards': 74, 'Walking away': 55, 'Injured': 48, 'Wrestling/Grappling': 44, "Can't tell": 41, 'Lying on ground': 21, 'Lights flashing': 11, 'Moving': 8, '': 7, 'Running away': 6, 'Civilian Clothing': 4, 'Yelling/Gesticulating': 4, 'Mentally Distressed/Confused': 4, 'Exiting a vehicle': 1, 'Questioning/Talking to': 1}
#
# Video # 15
# FN:  476
# FP:  41
# TN:  2
# avg IOU 0.5901925750190142
# total IOU 571.3064126184058
# Total Matches 968
# Precision 0.9593657086223984
# Recall 0.6703601108033241
# Number of Boxes for 1st 1444
# Authors of 1st ['16730']
# Labels of 1st {'Police Officer': 849, 'Civilian': 297, 'First Person POV': 279, 'Police Vehicle': 19}
# Actions of 1st: {'Unable to tell': 1266, 'Unable to determine': 1157, 'Holding person': 655, 'Uniform': 577, "Can't tell": 551, 'Sitting/Kneeling/Crouching on ground': 454, 'Standing': 421, 'Lying on ground': 256, 'Male': 248, 'Black or African American': 112, 'Injured': 111, 'Wrestling/Grappling': 90, 'Putting on PPE (e.g. gloves)': 41, 'White': 40, 'Handcuffing': 35, 'Parked': 19, 'Other': 19, 'Walking towards': 6, 'Native Hawaiian or Other Pacific Islander': 4, '': 4, 'Lights flashing': 2}
# Number of Boxes for 2nd 1009
# Authors of 2nd ['16733', '16731', '0']
# Labels of 2st {'Police Officer': 469, 'Civilian': 280, 'First Person POV': 243, 'Police Vehicle': 16}
# Actions of 2st: {'': 1177, 'Male': 509, 'Holding person': 507, 'Uniform': 409, 'Unable to tell': 342, 'Sitting/Kneeling/Crouching on ground': 314, 'Lying on ground': 287, 'Injured': 231, 'Handcuffing': 182, 'Standing': 152, 'Unable to determine': 139, 'White': 92, 'Putting on PPE (e.g. gloves)': 36, 'Kneeling on person': 34, 'Wrestling/Grappling': 31, "Can't tell": 24, 'Pulling away': 20, 'Parked': 16, 'Walking towards': 13, 'Walking away': 6, 'Lights flashing': 5, 'Exiting a vehicle': 3, 'Frisking (search of person)': 3}
#
# Video # 16
# FN:  60
# FP:  9
# TN:  8
# avg IOU 0.5009944630033961
# total IOU 32.06364563221735
# Total Matches 64
# Precision 0.8767123287671232
# Recall 0.5161290322580645
# Number of Boxes for 1st 124
# Authors of 1st ['16730', '0']
# Labels of 1st {'Civilian': 66, 'Police Officer': 30, 'First Person POV': 28}
# Actions of 1st: {'Male': 71, 'Unable to tell': 66, 'Black or African American': 53, 'Standing': 48, 'Unable to determine': 48, "Can't tell": 43, 'Questioning/Talking to': 19, 'Uniform': 12, 'Walking towards': 8, 'White': 5, 'Walking away': 5, 'Other': 5, 'Civilian clothing': 3, 'Entering door/building': 2, 'Exiting door/building': 2}
# Number of Boxes for 2nd 73
# Authors of 2nd ['16731', '16735']
# Labels of 2st {'First Person POV': 41, 'Civilian': 32}
# Actions of 2st: {'Male': 73, 'Unable to tell': 41, "Can't tell": 41, 'Mentally Distressed/Confused': 32, 'Black or African American': 32, 'Reaching for license': 27, 'Questioning/Talking to': 27}
#
# Video # 17
# FN:  3
# FP:  63
# TN:  7
# avg IOU 0.644782175292178
# total IOU 49.00344532220553
# Total Matches 76
# Precision 0.5467625899280576
# Recall 0.9620253164556962
# Number of Boxes for 1st 79
# Authors of 1st ['16730', '0']
# Labels of 1st {'Civilian': 56, 'First Person POV': 15, 'Police Officer': 8}
# Actions of 1st: {'Male': 53, 'Black or African American': 52, 'Unable to determine': 26, 'Unable to tell': 26, 'Questioning/Talking to': 25, 'Standing': 21, "Can't tell": 15, 'Walking away': 10, 'Uniform': 8, 'Exiting door/building': 6, 'Entering door/building': 2, 'White': 1}
# Number of Boxes for 2nd 139
# Authors of 2nd ['16731', '0', '16734']
# Labels of 2st {'First Person POV': 71, 'Civilian': 57, 'Police Officer': 2, '': 1}
# Actions of 2st: {'Unable to determine': 66, 'Unable to tell': 66, "Can't tell": 66, 'Male': 58, 'Black or African American': 57, 'Sitting/Kneeling/Crouching on ground': 56, 'Questioning/Talking to': 49, 'Standing': 32, 'Sitting': 18, '': 17, 'Walking away': 17, 'Leaving scene': 16, 'Walking towards': 6, 'Searching (search of a place or space)': 1, 'Female': 1, 'White': 1, 'Uniform': 1}
#
# Video # 18
# FN:  92
# FP:  24
# TN:  68
# avg IOU 0.5359030689000674
# total IOU 33.76189334070425
# Total Matches 63
# Precision 0.7241379310344828
# Recall 0.4064516129032258
# Number of Boxes for 1st 155
# Authors of 1st ['16735']
# Labels of 1st {'Police Officer': 150, 'Civilian': 3, '': 2}
# Actions of 1st: {'Uniform': 150, 'Male': 141, 'White': 112, 'Standing': 89, 'Questioning/Talking to': 25, 'Walking away': 25, 'Walking towards': 21, 'Sitting/Kneeling/Crouching on ground': 19, 'Unable to tell': 17, 'Hispanic or Latino': 13, 'Black or African American': 11, 'Holding person': 11, 'Female': 11, 'Leaving scene': 10, 'Has firearm': 5, 'Lying on ground': 3, 'Raising hands': 1, '': 1}
# Number of Boxes for 2nd 87
# Authors of 2nd ['16731', '0']
# Labels of 2st {'Police Officer': 47, 'First Person POV': 25, 'Civilian': 4}
# Actions of 2st: {'Unable to tell': 59, 'Unable to determine': 47, 'Uniform': 47, 'Male': 39, 'Standing': 33, 'Sitting/Kneeling/Crouching on ground': 24, "Can't tell": 24, 'Walking away': 19, 'Leaving scene': 19, 'White': 16, 'Holding person': 13, 'Wrestling/Grappling': 13, 'Black or African American': 11, 'Walking towards': 6, 'Lying on ground': 4, '': 3, 'Has firearm': 2}
#
# Video # 19
# FN:  52
# FP:  232
# TN:  230
# avg IOU 0.4406569668339561
# total IOU 77.99628312961023
# Total Matches 177
# Precision 0.43276283618581907
# Recall 0.7729257641921398
# Number of Boxes for 1st 229
# Authors of 1st ['0', '16734']
# Labels of 1st {'Civilian': 80, 'First Person POV': 44, 'Police Officer': 28}
# Actions of 1st: {'Male': 180, '': 166, 'Black or African American': 98, 'Has taser': 50, 'Sitting/Kneeling/Crouching on ground': 44, 'Running away': 33, 'Walking towards': 31, 'Uniform': 18, 'Standing': 11, 'Female': 10}
# Number of Boxes for 2nd 409
# Authors of 2nd ['16733', '0']
# Labels of 2st {'First Person POV': 237, 'Civilian': 116, 'Police Officer': 49, 'Police Vehicle': 6}
# Actions of 2st: {'White': 263, 'Uniform': 256, 'Female': 233, 'Questioning/Talking to': 174, 'Standing': 138, 'Male': 120, 'Black or African American': 118, 'Running towards': 83, 'Sitting/Kneeling/Crouching on ground': 70, 'Has taser': 64, '': 45, 'Yelling/Gesticulating': 44, 'Walking away': 39, 'Unable to determine': 35, 'Walking towards': 23, 'Raising hands': 23, 'Leaving scene': 15, 'Exiting door/building': 13, 'Exiting a vehicle': 11, 'Reaching for license': 10, 'Running away': 10, 'Unable to tell': 7, "Can't tell": 7, 'Sitting': 7, 'Reaching license': 6, 'Pulling away': 6, 'Parked': 6, 'Lights flashing': 6, 'Exiting vehicle': 6, 'Lying on ground': 5, 'Entering door/building': 4, 'Entering a police vehicle': 4, 'Civilian Clothing': 4, 'Handcuffing': 3, 'Drawing a weapon': 3, 'Searching (search of place or space)': 2, 'Injured': 2, 'Knocking': 1, 'Defending (self)': 1, 'Kneeling on person': 1, 'Holding person': 1}
#
# Video # 20
# FN:  92
# FP:  38
# TN:  330
# avg IOU 0.5166733976275857
# total IOU 104.88469971839989
# Total Matches 203
# Precision 0.8423236514522822
# Recall 0.688135593220339
# Number of Boxes for 1st 295
# Authors of 1st ['16725']
# Labels of 1st {'Police Officer': 174, 'Civilian': 66, 'First Person POV': 31, 'Police Vehicle': 24}
# Actions of 1st: {'': 228, 'Male': 124, 'Civilian Clothing': 115, 'Female': 101, 'Sitting/Kneeling/Crouching on ground': 94, 'Holding person': 86, 'White': 84, 'Has taser': 74, 'Uniform': 52, 'Standing': 47, 'Black or African American': 36, 'Lying on ground': 36, 'Parked': 24, 'Lights flashing': 23, 'Reaching for license': 15, 'Running away': 11, "Can't tell": 7, 'Exiting a vehicle': 6, 'Walking away': 6, 'Frisking (search of person)': 3, 'Entering a police vehicle': 2, 'Kneeling on person': 1}
# Number of Boxes for 2nd 241
# Authors of 2nd ['16725', '16736']
# Labels of 2st {'Police Officer': 135, 'Civilian': 52, 'Police Vehicle': 28, 'First Person POV': 24, '': 2}
# Actions of 2st: {'White': 154, 'Uniform': 152, 'Has firearm': 119, 'Male': 102, 'Female': 88, 'Standing': 74, 'Black or African American': 50, 'Holding person': 45, 'Handcuffing': 29, '': 26, 'Parked': 25, 'Lights flashing': 25, 'Kneeling on person': 19, 'Walking away': 17, 'Frisking (search of person)': 16, 'Sitting/Kneeling/Crouching on ground': 15, 'Running away': 10, 'Lying on ground': 8, 'Has taser': 8, 'Exiting a vehicle': 7, 'Moving': 6, 'Wrestling/Grappling': 6, "Can't tell": 5, 'Reaching license': 4, 'Exiting vehicle': 4, 'Unable to tell': 4, 'Running towards': 3, 'Walking towards': 2, 'Raising hands': 2, 'Reaching for license': 2, 'Questioning/Talking to': 1}
#
# Video # 21
# FN:  4
# FP:  15
# TN:  59
# avg IOU 0.5839588377263554
# total IOU 18.686682807243372
# Total Matches 32
# Precision 0.6808510638297872
# Recall 0.8888888888888888
# Number of Boxes for 1st 36
# Authors of 1st ['16727']
# Labels of 1st {'Civilian': 29, 'First Person POV': 5, 'Police Officer': 2}
# Actions of 1st: {'Lying on ground': 21, 'Black or African American': 19, 'Unable to determine': 18, 'Male': 18, 'Injured': 18, 'Mentally Distressed/Confused': 11, 'Unable to tell': 10, 'White': 7, 'Standing': 5, "Can't tell": 5, 'Defending (self)': 5, 'Raising hands': 5, 'Entering door/building': 4, 'Drawing a weapon': 2, 'Walking towards': 2, 'Civilian Clothing': 2, 'Sitting/Kneeling/Crouching on ground': 1, 'Running away': 1}
# Number of Boxes for 2nd 47
# Authors of 2nd ['0', '16737']
# Labels of 2st {'Civilian': 30, 'First Person POV': 11, 'Police Officer': 6}
# Actions of 2st: {'Unable to tell': 29, 'Unable to determine': 28, 'Lying on ground': 22, 'Injured': 21, 'Male': 19, 'Black or African American': 15, "Can't tell": 11, 'Uniform': 6, 'Running towards': 5, 'Walking towards': 5, 'Sitting/Kneeling/Crouching on ground': 4, 'Has firearm': 4, 'Running away': 3, 'White': 3, 'Exiting door/building': 1, 'Standing': 1}
#
# Video # 22
# FN:  3
# FP:  1
# TN:  26
# avg IOU 0.5478876633741149
# total IOU 4.930988970367034
# Total Matches 9
# Precision 0.9
# Recall 0.75
# Number of Boxes for 1st 12
# Authors of 1st ['16727', '0']
# Labels of 1st {'Police Officer': 6, 'Bystander': 5, 'Civilian': 1}
# Actions of 1st: {"Can't tell": 5, 'Male': 5, 'White': 5, 'Walking towards': 3, 'Standing': 3, 'Unable to determine': 2, 'Unable to tell': 2, 'Has firearm': 1, 'Holstering a weapon': 1, 'Uniform': 1, 'Lying on ground': 1}
# Number of Boxes for 2nd 10
# Authors of 2nd ['16734']
# Labels of 2st {'Civilian': 5, 'Police Officer': 5}
# Actions of 2st: {'Male': 6, 'Black or African American': 5, 'Standing': 5, '': 5, 'Uniform': 5, 'Has firearm': 4, 'Female': 3, 'Unable to determine': 1}
#
# Video # 23
# FN:  43
# FP:  314
# TN:  165
# avg IOU 0.5563920887170688
# total IOU 42.28579874249723
# Total Matches 76
# Precision 0.19487179487179487
# Recall 0.6386554621848739
# Number of Boxes for 1st 119
# Authors of 1st ['16727', '0', '16736']
# Labels of 1st {'Police Officer': 31, 'Police Vehicle': 19, 'Civilian': 17, 'First Person POV': 5}
# Actions of 1st: {'Standing': 76, '': 63, 'Male': 61, 'White': 50, "Can't tell": 50, 'Unable to determine': 21, 'Parked': 19, 'Civilian Clothing': 18, 'Unable to tell': 16, 'Lights flashing': 14, 'Sitting/Kneeling/Crouching on ground': 12, 'Questioning/Talking to': 10, 'Walking away': 4, 'Black or African American': 4, 'Has firearm': 2}
# Number of Boxes for 2nd 390
# Authors of 2nd ['16730', '0']
# Labels of 2st {'Police Officer': 224, 'Civilian': 97, 'First Person POV': 38, 'Police Vehicle': 30}
# Actions of 2st: {'Male': 253, 'Standing': 193, 'Unable to tell': 159, 'Uniform': 154, 'Unable to determine': 99, 'Hispanic or Latino': 94, "Can't tell": 76, 'White': 76, 'Questioning/Talking to': 60, 'Walking towards': 56, 'Walking away': 39, 'Searching (search of a place or space)': 39, 'Lights flashing': 29, '': 28, 'Searching vehicle': 28, 'Civilian Clothing': 27, 'Parked': 22, 'Searching (search of place or space)': 14, 'Black or African American': 14, 'Sitting': 13, 'Yelling/Gesticulating': 10, 'Searching a vehicle': 9, 'Leaving scene': 8, 'Moving': 7, 'Entering a police vehicle': 3}
#
# Video # 24
# FN:  33
# FP:  67
# TN:  340
# avg IOU 0.6813837793896478
# total IOU 14.990443146572252
# Total Matches 22
# Precision 0.24719101123595505
# Recall 0.4
# Number of Boxes for 1st 55
# Authors of 1st ['16725']
# Labels of 1st {'Police Officer': 45, 'First Person POV': 10}
# Actions of 1st: {'': 79, 'Male': 43, 'Uniform': 43, 'Standing': 33, 'Lying on ground': 10, 'Running towards': 6, 'Holding person': 4, 'Exiting vehicle': 2}
# Number of Boxes for 2nd 89
# Authors of 2nd ['16733']
# Labels of 2st {'First Person POV': 77, 'Civilian': 12}
# Actions of 2st: {'Unable to determine': 82, 'Unable to tell': 82, "Can't tell": 77, 'Walking towards': 31, 'Walking away': 28, 'Has firearm': 26, 'Lying on ground': 12, 'Injured': 12, 'Running towards': 10, 'Male': 7, 'White': 7, 'Standing': 6, 'Frisking (search of person)': 6, 'Sitting': 2, 'Exiting a vehicle': 2, 'Raising hands': 1}
#
# Video # 25
# FN:  28
# FP:  127
# TN:  145
# avg IOU 0.7043427071011219
# total IOU 75.36466965982004
# Total Matches 107
# Precision 0.45726495726495725
# Recall 0.7925925925925926
# Number of Boxes for 1st 135
# Authors of 1st ['16730', '0']
# Labels of 1st {'Police Officer': 96, 'First Person POV': 28, 'Civilian': 7, 'Police Vehicle': 4}
# Actions of 1st: {'Unable to tell': 131, 'Standing': 87, "Can't tell": 81, 'Unable to determine': 70, 'Male': 61, 'Uniform': 43, 'Walking away': 37, 'Lying on ground': 12, 'Has firearm': 9, 'Sitting/Kneeling/Crouching on ground': 8, 'Searching (search of place or space)': 7, 'Wrestling/Grappling': 4, 'Holding person': 4, 'Lights flashing': 4, 'Moving': 4, 'Kneeling on': 3, 'Drawing a weapon': 1, 'Walking towards': 1}
# Number of Boxes for 2nd 234
# Authors of 2nd ['16726', '0']
# Labels of 2st {'Police Officer': 99, 'Police Vehicle': 82, 'Civilian': 25, 'First Person POV': 22}
# Actions of 2st: {'Male': 117, 'Uniform': 110, 'White': 100, 'Standing': 78, 'Parked': 78, 'Has firearm': 77, 'Leaving scene': 65, 'Unable to tell': 35, 'Placing into police vehicle': 35, '': 31, 'Walking away': 29, 'Unable to determine': 19, 'Walking towards': 17, 'Lying on ground': 14, 'Injured': 12, 'Running towards': 10, 'Drawing a weapon': 10, 'Exiting vehicle': 5, 'Lights flashing': 5, 'Moving': 4, 'Defending (someone else)': 3, 'Defending (self)': 3, 'Entering police vehicle': 3, 'Searching (search of place or space)': 2, 'Searching a vehicle': 2, 'Reaching for weapon': 2, 'Questioning/Talking to': 1, 'Pulling away': 1, 'Running away': 1, "Can't tell": 1}
#
# Video # 26
# FN:  38
# FP:  61
# TN:  2
# avg IOU 0.5914261865047167
# total IOU 263.18465299459893
# Total Matches 445
# Precision 0.8794466403162056
# Recall 0.9213250517598344
# Number of Boxes for 1st 483
# Authors of 1st ['16725']
# Labels of 1st {'Police Officer': 314, 'Civilian': 138, 'First Person POV': 20, 'Police Vehicle': 11}
# Actions of 1st: {'Male': 452, 'Standing': 312, 'Uniform': 255, 'White': 198, 'Black or African American': 150, '': 122, 'Holding person': 114, 'Hispanic or Latino': 101, 'Handcuffing': 36, 'Frisking (search of a person)': 31, 'Searching a vehicle': 15, 'Parked': 11, 'Entering a police vehicle': 5, 'Walking away': 2}
# Number of Boxes for 2nd 506
# Authors of 2nd ['16731', '0']
# Labels of 2st {'Police Officer': 325, 'Civilian': 137, 'First Person POV': 37, 'Police Vehicle': 7}
# Actions of 2st: {'Male': 345, 'Standing': 316, '': 316, 'Uniform': 264, 'Unable to tell': 174, 'Hispanic or Latino': 105, 'White': 83, "Can't tell": 56, 'Holding person': 42, 'Frisking (search of a person)': 38, 'Searching vehicle': 25, 'Searching a vehicle': 18, 'Unable to determine': 17, 'Handcuffing': 17, 'Questioning/Talking to': 12, 'Parked': 7, 'Walking towards': 6, 'Lights flashing': 6, 'Entering a police vehicle': 5, 'Walking away': 3, 'Yelling/Gesticulating': 2}
#
# Video # 27
# FN:  0
# FP:  382
# TN:  3
# avg IOU 0.565598997874678
# total IOU 36.763934861854075
# Total Matches 65
# Precision 0.14541387024608501
# Recall 1.0
# Number of Boxes for 1st 65
# Authors of 1st ['16736', '16737']
# Labels of 1st {'Police Officer': 34, 'First Person POV': 19, 'Civilian': 12}
# Actions of 1st: {'White': 43, 'Unable to determine': 35, 'Uniform': 29, 'Standing': 29, 'Male': 28, 'Has firearm': 23, "Can't tell": 21, 'Unable to tell': 18, 'Lying on ground': 12, '': 6, 'Walking towards': 4, 'Putting on PPE (e.g. gloves)': 4, 'Yelling/Gesticulating': 2, 'Black or African American': 2, 'Civilian Clothing': 1}
# Number of Boxes for 2nd 447
# Authors of 2nd ['16726', '0']
# Labels of 2st {'Police Officer': 370, 'First Person POV': 38, 'Civilian': 13}
# Actions of 2st: {'Standing': 397, 'Male': 397, 'Has firearm': 283, 'White': 265, 'Uniform': 202, 'Civilian Clothing': 140, 'Has taser': 132, 'Unable to tell': 116, 'Walking towards': 91, "Can't tell": 66, 'Questioning/Talking to': 50, 'Walking away': 46, '': 39, 'Holstering a weapon': 37, 'Putting on PPE (e.g. gloves)': 30, 'Black or African American': 25, 'Lying on ground': 13, 'Injured': 13, 'Yelling/Gesticulating': 11, 'Drawing a weapon': 6, 'Leaving scene': 6, 'Reaching for weapon': 1}
#
# Video # 28
# FN:  8
# FP:  181
# TN:  72
# avg IOU 0.573435996767586
# total IOU 43.58113575433654
# Total Matches 76
# Precision 0.29571984435797666
# Recall 0.9047619047619048
# Number of Boxes for 1st 84
# Authors of 1st ['16736', '16737']
# Labels of 1st {'Police Officer': 60, 'First Person POV': 13, 'Civilian': 10, 'Police Vehicle': 1}
# Actions of 1st: {'White': 40, 'Male': 38, 'Uniform': 37, 'Unable to determine': 34, 'Standing': 34, 'Unable to tell': 32, '': 22, 'Civilian Clothing': 20, "Can't tell": 16, 'Walking away': 13, 'Has firearm': 12, 'Lying on ground': 10, 'Reaching for weapon': 4, 'Putting on PPE (e.g. gloves)': 4, 'Running away': 2, 'Parked': 1}
# Number of Boxes for 2nd 257
# Authors of 2nd ['16738', '16733', '0']
# Labels of 2st {'Police Officer': 208, 'First Person POV': 36, 'Civilian': 11, 'Police Vehicle': 1}
# Actions of 2st: {'Standing': 175, 'Uniform': 142, 'Male': 132, 'Unable to tell': 127, 'Unable to determine': 124, 'White': 118, "Can't tell": 68, 'Walking towards': 65, 'Questioning/Talking to': 36, 'Civilian Clothing': 34, 'Has firearm': 20, 'Yelling/Gesticulating': 13, 'Lying on ground': 11, 'Black or African American': 10, 'Raising hands': 6, 'Running towards': 5, 'Holstering a weapon': 5, 'Putting on PPE (e.g. gloves)': 5, 'Walking away': 4, '': 2, 'Drawing a weapon': 1, 'Parked': 1, 'Entering door/building': 1}
#
# Video # 29
# FN:  107
# FP:  7
# TN:  36
# avg IOU 0.6095109355033242
# total IOU 25.59945929113962
# Total Matches 42
# Precision 0.8571428571428571
# Recall 0.28187919463087246
# Number of Boxes for 1st 149
# Authors of 1st ['16736']
# Labels of 1st {'Police Officer': 135, 'Civilian': 8, 'First Person POV': 6}
# Actions of 1st: {'Uniform': 132, 'Standing': 105, 'Male': 100, '': 67, 'Unable to tell': 65, 'White': 49, 'Unable to determine': 23, 'Walking towards': 15, 'Walking away': 14, 'Sitting/Kneeling/Crouching on ground': 8, 'Has firearm': 6, 'Questioning/Talking to': 4, 'Drawing a weapon': 3, "Can't tell": 3, 'Yelling/Gesticulating': 3, 'Holstering a weapon': 2, 'Searching (search of a place or space)': 1}
# Number of Boxes for 2nd 49
# Authors of 2nd ['16725', '16731']
# Labels of 2st {'Police Officer': 39, 'First Person POV': 5, 'Civilian': 4}
# Actions of 2st: {'Unable to tell': 35, 'Male': 35, 'Uniform': 33, 'Standing': 18, '': 12, 'Unable to determine': 10, 'White': 9, 'Has firearm': 6, "Can't tell": 6, 'Walking towards': 4, 'Lying on ground': 4, 'Homeless': 4, 'Drawing a weapon': 2, 'Questioning/Talking to': 2, 'Sitting/Kneeling/Crouching on ground': 2, 'Exiting a vehicle': 1, 'Walking away': 1}
#
# Video # 30
# FN:  48
# FP:  45
# TN:  125
# avg IOU 0.6412087822774076
# total IOU 31.419230331592974
# Total Matches 49
# Precision 0.5212765957446809
# Recall 0.5051546391752577
# Number of Boxes for 1st 97
# Authors of 1st ['16736', '16737']
# Labels of 1st {'Civilian': 35, 'Police Officer': 31, 'Police Vehicle': 30, 'First Person POV': 1}
# Actions of 1st: {'Unable to tell': 50, 'Unable to determine': 41, 'Uniform': 31, 'Parked': 30, 'Walking away': 29, 'Male': 25, 'Standing': 20, 'Walking towards': 17, 'Entering door/building': 11, 'White': 11, 'Black or African American': 6, "Can't tell": 1, 'Female': 1}
# Number of Boxes for 2nd 94
# Authors of 2nd ['16725', '0']
# Labels of 2st {'Police Officer': 36, 'Civilian': 33, 'Police Vehicle': 11, '': 10, 'First Person POV': 2}
# Actions of 2st: {'': 51, 'Male': 45, 'Uniform': 35, 'Entering door/building': 27, 'Unable to tell': 27, 'Parked': 11, 'White': 10, 'Standing': 8, 'Female': 7, 'Walking towards': 6, 'Black or African American': 6, 'Asian': 2, 'Yelling/Gesticulating': 1}
#
# Video # 31
# FN:  195
# FP:  207
# TN:  98
# avg IOU 0.46074112651078003
# total IOU 240.96760916513796
# Total Matches 523
# Precision 0.7164383561643836
# Recall 0.7284122562674095
# Number of Boxes for 1st 718
# Authors of 1st ['16725']
# Labels of 1st {'Police Officer': 394, 'First Person POV': 223, 'Civilian': 101}
# Actions of 1st: {'Male': 663, 'White': 524, 'Has firearm': 444, 'Standing': 385, 'Uniform': 298, '': 281, 'Drawing a weapon': 252, 'Holding person': 225, 'Injured': 101, 'Black or African American': 100, "Can't tell": 83, 'Sitting/Kneeling/Crouching on ground': 64, 'Civilian Clothing': 45, 'Female': 37, 'Unable to tell': 22, 'Putting on PPE (e.g. gloves)': 20, 'Searching vehicle': 19, 'Running towards': 11, 'Exiting a vehicle': 3}
# Number of Boxes for 2nd 730
# Authors of 2nd ['16725', '16731', '16736']
# Labels of 2st {'Police Officer': 507, 'First Person POV': 132, 'Civilian': 91}
# Actions of 2st: {'Male': 694, 'Has firearm': 536, 'White': 477, 'Civilian Clothing': 371, 'Standing': 346, 'Drawing a weapon': 232, 'Unable to tell': 160, '': 138, 'Uniform': 135, 'Injured': 91, 'Black or African American': 91, 'Sitting/Kneeling/Crouching on ground': 76, 'Exiting a vehicle': 55, 'Searching vehicle': 52, 'Walking away': 42, 'Yelling/Gesticulating': 39, 'Holding person': 36, 'Sitting': 34, 'Running away': 19, 'Unable to determine': 16, 'Kneeling on': 15, 'Questioning/Talking to': 13, 'Other': 13, 'Putting on PPE (e.g. gloves)': 10, 'Female': 4, 'Holstering a weapon': 3, 'Running towards': 2, 'Searching (search of place or space)': 2, 'Reaching for weapon': 1, 'Walking towards': 1}
#
# Video # 32
# FN:  291
# FP:  113
# TN:  157
# avg IOU 0.5285553457240384
# total IOU 113.11084398494421
# Total Matches 214
# Precision 0.654434250764526
# Recall 0.42376237623762375
# Number of Boxes for 1st 505
# Authors of 1st ['16738', '0']
# Labels of 1st {'Police Officer': 355, 'First Person POV': 105, 'Civilian': 45}
# Actions of 1st: {'Standing': 449, 'Unable to tell': 402, 'Male': 257, 'Holstering a weapon': 192, 'Civilian Clothing': 183, 'Uniform': 169, 'Unable to determine': 148, 'Has firearm': 138, "Can't tell": 107, 'Searching (search of a place or space)': 107, 'Searching vehicle': 107, 'Female': 99, 'Hispanic or Latino': 76, 'Holding person': 45, 'Pulling away': 30, 'Injured': 28, 'Black or African American': 16, 'White': 10, 'Sitting/Kneeling/Crouching on ground': 5, 'Yelling/Gesticulating': 5, 'Questioning/Talking to': 5, 'Walking towards': 3, '': 3, 'Exiting a vehicle': 2}
# Number of Boxes for 2nd 327
# Authors of 2nd ['0', '16736', '16728']
# Labels of 2st {'First Person POV': 184, 'Police Officer': 140, 'Civilian': 3}
# Actions of 2st: {'Has firearm': 256, 'Unable to tell': 229, 'Standing': 197, 'Unable to determine': 193, 'Drawing a weapon': 188, "Can't tell": 185, 'Male': 102, 'Civilian Clothing': 95, 'White': 66, 'Walking away': 45, 'Uniform': 44, 'Has taser': 33, 'Female': 32, 'Black or African American': 31, 'Searching vehicle': 25, 'Searching (search of a place or space)': 19, 'Sitting/Kneeling/Crouching on ground': 5, 'Questioning/Talking to': 4, 'Yelling/Gesticulating': 3, 'Injured': 3, 'Holding person': 2, 'Exiting a vehicle': 1, 'Hispanic or Latino': 1, 'Reaching for weapon': 1, 'Handcuffing': 1}
#
# Video # 33
# FN:  6
# FP:  817
# TN:  35
# avg IOU 0.5823826637866203
# total IOU 112.98223677460435
# Total Matches 194
# Precision 0.19188921859545005
# Recall 0.97
# Number of Boxes for 1st 200
# Authors of 1st ['16725', '16737']
# Labels of 1st {'Police Officer': 145, 'First Person POV': 48, 'Police Vehicle': 7}
# Actions of 1st: {'Standing': 144, 'Uniform': 143, 'White': 138, 'Male': 134, 'Has firearm': 128, '': 108, 'Drawing a weapon': 86, 'Unable to tell': 34, 'Unable to determine': 17, 'Walking towards': 16, 'Reaching for weapon': 12, 'Parked': 7, 'Lights flashing': 7, "Can't tell": 4, 'Running away': 3, 'Civilian Clothing': 1, 'Walking away': 1, 'Sitting/Kneeling/Crouching on ground': 1}
# Number of Boxes for 2nd 1011
# Authors of 2nd ['16727']
# Labels of 2st {'Police Officer': 861, 'First Person POV': 73, 'Ambulance': 42, 'Police Vehicle': 33, '': 2}
# Actions of 2st: {'Male': 662, 'Standing': 613, 'Uniform': 597, 'White': 567, 'Unable to determine': 249, 'Has firearm': 228, 'Unable to tell': 217, "Can't tell": 168, 'Civilian Clothing': 166, 'Black or African American': 133, 'Walking away': 103, 'Walking towards': 86, 'Drawing a weapon': 81, 'Parked': 59, 'Lights flashing': 55, 'Holding person': 22, 'Searching (search of a place or space)': 19, 'Female': 19, '': 16, 'Reaching for weapon': 10, 'Hispanic or Latino': 9, 'Moving': 7, 'Native Hawaiian or Other Pacific Islander': 5, 'Holstering a weapon': 4, 'Running away': 3, 'Searching vehicle': 2, 'Sitting/Kneeling/Crouching on ground': 2, 'Putting on PPE (e.g. gloves)': 2, 'Defending (self)': 1, 'Defending (someone else)': 1, 'Running towards': 1, 'Entering police vehicle': 1}
#
# Video # 34
# FN:  9
# FP:  777
# TN:  42
# avg IOU 0.5853487721833712
# total IOU 133.45952005780865
# Total Matches 228
# Precision 0.22686567164179106
# Recall 0.9620253164556962
# Number of Boxes for 1st 237
# Authors of 1st ['16737']
# Labels of 1st {'First Person POV': 135, 'Police Officer': 89, 'Ambulance': 5, 'Bystander': 5, 'Civilian': 2, 'Police Vehicle': 1}
# Actions of 1st: {'White': 181, 'Has firearm': 173, "Can't tell": 172, 'Drawing a weapon': 167, 'Unable to determine': 164, 'Walking away': 125, 'Standing': 76, 'Male': 60, 'Uniform': 51, 'Unable to tell': 45, 'Sitting/Kneeling/Crouching on ground': 12, 'Defending (self)': 9, 'Parked': 6, 'Reaching for weapon': 5, 'Lights flashing': 5, 'Other': 2, 'Lying on ground': 2, 'Exiting a vehicle': 1, 'Civilian Clothing': 1, 'Leaving scene': 1}
# Number of Boxes for 2nd 1005
# Authors of 2nd ['0', '16734', '16735']
# Labels of 2st {'Police Officer': 390, 'First Person POV': 164, 'Police Vehicle': 6}
# Actions of 2st: {'': 2032, 'Male': 462, 'Standing': 278, 'Has firearm': 260, 'Uniform': 187, 'Walking towards': 71, 'Unable to tell': 26, 'Black or African American': 23, 'Running towards': 15, 'White': 13, 'Female': 11, 'Sitting/Kneeling/Crouching on ground': 10, 'Holstering a weapon': 9, 'Parked': 6, 'Searching (search of a place or space)': 5}
#
# Video # 35
# FN:  42
# FP:  121
# TN:  9
# avg IOU 0.5825886049067821
# total IOU 125.25655005495815
# Total Matches 215
# Precision 0.6398809523809523
# Recall 0.8365758754863813
# Number of Boxes for 1st 257
# Authors of 1st ['16725']
# Labels of 1st {'Police Officer': 144, 'First Person POV': 58, 'Civilian': 55}
# Actions of 1st: {'Male': 243, 'Standing': 188, 'White': 179, '': 146, 'Has firearm': 143, 'Holding person': 84, 'Uniform': 68, 'Drawing a weapon': 51, 'Injured': 51, "Can't tell": 44, 'Unable to tell': 17, 'Black or African American': 12, 'Putting on PPE (e.g. gloves)': 8, 'Civilian Clothing': 7}
# Number of Boxes for 2nd 336
# Authors of 2nd ['16731', '0', '16734']
# Labels of 2st {'Police Officer': 173, 'First Person POV': 49, 'Civilian': 42}
# Actions of 2st: {'': 474, 'Standing': 225, 'Male': 208, 'Uniform': 181, 'Has firearm': 70, 'Holding person': 58, 'White': 46, 'Sitting/Kneeling/Crouching on ground': 44, 'Black or African American': 35, 'Showing aggression': 17, 'Civilian clothing': 9, 'Female': 5, 'Unable to determine': 2, 'Unable to tell': 2, 'Frisking (search of a person)': 1, "Can't tell": 1}
#
# Video # 36
# FN:  48
# FP:  71
# TN:  190
# avg IOU 0.692300682065456
# total IOU 238.1514346305169
# Total Matches 344
# Precision 0.8289156626506025
# Recall 0.8775510204081632
# Number of Boxes for 1st 392
# Authors of 1st ['16727']
# Labels of 1st {'Police Officer': 257, 'Civilian': 65, 'Police Vehicle': 55, 'First Person POV': 15}
# Actions of 1st: {'Uniform': 213, 'Unable to determine': 191, 'Unable to tell': 161, 'White': 137, 'Lying on ground': 134, 'Standing': 126, 'Male': 122, 'Has firearm': 111, 'Parked': 55, "Can't tell": 50, 'Injured': 39, '': 35, 'Sitting/Kneeling/Crouching on ground': 34, 'Black or African American': 31, 'Entering door/building': 11, 'Holding person': 10, 'Has taser': 8, 'Walking towards': 7, 'Running towards': 6, 'Female': 6, 'Walking away': 4, 'Searching (search of a place or space)': 4, 'Exiting a vehicle': 2, 'Mentally Distressed/Confused': 2, 'Entering a police vehicle': 1, 'Reaching for weapon': 1}
# Number of Boxes for 2nd 415
# Authors of 2nd ['16726', '0']
# Labels of 2st {'Police Officer': 248, 'Police Vehicle': 76, 'Civilian': 67, 'First Person POV': 20}
# Actions of 2st: {'Male': 297, 'Uniform': 256, 'Unable to tell': 216, 'Standing': 164, 'Lying on ground': 148, 'Holding person': 139, 'White': 118, 'Wrestling/Grappling': 84, 'Parked': 79, 'Handcuffing': 63, 'Injured': 60, 'Entering door/building': 32, 'Unable to determine': 27, 'Walking away': 21, 'Exiting door/building': 13, 'Female': 12, "Can't tell": 11, 'Has firearm': 11, 'Walking towards': 10, 'Leaving scene': 9, 'Sitting/Kneeling/Crouching on ground': 9, 'Running towards': 8, 'Sitting': 7, 'Exiting a vehicle': 7, 'Reaching for weapon': 6, 'Knocking': 4, 'Placing into police vehicle': 3, 'Defending (someone else)': 3, 'Knocking down door': 2, 'Black or African American': 2, 'Has taser': 1, 'Putting on PPE (e.g. gloves)': 1}
#
# Video # 37
# FN:  46
# FP:  9
# TN:  188
# avg IOU 0.6703078106767172
# total IOU 89.15093882000339
# Total Matches 133
# Precision 0.9366197183098591
# Recall 0.7430167597765364
# Number of Boxes for 1st 179
# Authors of 1st ['16736']
# Labels of 1st {'Police Officer': 170, 'Police Vehicle': 5, 'First Person POV': 3, 'Civilian': 1}
# Actions of 1st: {'Uniform': 155, 'Standing': 124, 'Male': 91, 'Unable to tell': 76, '': 63, 'White': 57, 'Unable to determine': 44, 'Walking away': 35, "Can't tell": 15, 'Reaching for weapon': 13, 'Female': 11, 'Questioning/Talking to': 9, 'Entering door/building': 8, 'Black or African American': 6, 'Parked': 5, 'Lying on ground': 3, 'Native Hawaiian or Other Pacific Islander': 3, 'Exiting a vehicle': 2, 'Running away': 1, 'Yelling/Gesticulating': 1, 'Holding person': 1, 'Wrestling/Grappling': 1, 'Sitting/Kneeling/Crouching on ground': 1, 'Exiting door/building': 1}
# Number of Boxes for 2nd 142
# Authors of 2nd ['16725']
# Labels of 2st {'Police Officer': 135, 'Police Vehicle': 4, 'First Person POV': 3}
# Actions of 2st: {'Uniform': 135, 'Male': 124, 'White': 112, 'Standing': 48, 'Has firearm': 29, 'Reaching for weapon': 12, '': 11, 'Walking away': 10, 'Black or African American': 10, 'Female': 8, 'Knocking': 7, 'Unable to tell': 6, 'Lying on ground': 5, 'Injured': 5, 'Hispanic or Latino': 5, 'Parked': 4, 'Unable to determine': 3, 'Running away': 2, 'Entering door/building': 2, 'Exiting a vehicle': 1, 'Sitting/Kneeling/Crouching on ground': 1, 'Holstering a weapon': 1}
#
# Video # 38
# FN:  251
# FP:  30
# TN:  142
# avg IOU 0.6590162364390837
# total IOU 163.43602663689276
# Total Matches 248
# Precision 0.8920863309352518
# Recall 0.4969939879759519
# Number of Boxes for 1st 499
# Authors of 1st ['16730', '0']
# Labels of 1st {'Civilian': 223, 'First Person POV': 165, 'Police Officer': 102, 'Police Vehicle': 8}
# Actions of 1st: {'Unable to tell': 441, 'Unable to determine': 409, 'Lying on ground': 223, "Can't tell": 204, 'Holding person': 118, 'Kneeling on': 93, 'Standing': 90, 'Male': 73, 'Uniform': 64, 'White': 49, 'Entering door/building': 32, 'Wrestling/grappling': 31, 'Searching (search of a place or space)': 19, 'Injured': 13, 'Wrestling/Grappling': 13, 'Walking away': 11, 'Walking towards': 11, 'Searching (search of place or space)': 11, 'Has firearm': 11, 'Other': 9, 'Parked': 8, 'Handcuffing': 5, 'Two or more': 1}
# Number of Boxes for 2nd 278
# Authors of 2nd ['16731', '16726', '0', '16735']
# Labels of 2st {'Police Officer': 96, 'First Person POV': 90, 'Civilian': 78, 'Police Vehicle': 7}
# Actions of 2st: {'Male': 244, 'White': 157, 'Uniform': 133, 'Entering door/building': 95, 'Standing': 94, 'Has firearm': 85, 'Lying on ground': 78, 'Injured': 78, 'Unable to tell': 67, 'Holding person': 62, 'Has taser': 59, "Can't tell": 53, '': 47, 'Kneeling on': 26, 'Walking away': 21, 'Walking towards': 18, 'Handcuffing': 14, 'Unable to determine': 13, 'Wrestling/Grappling': 8, 'Parked': 7, 'Running towards': 5, 'Showing aggression': 5, 'Exiting door/building': 3, 'Searching (search of place or space)': 1, 'Raising hands': 1}
#
# Video # 39
# FN:  21
# FP:  281
# TN:  210
# avg IOU 0.5300496788938951
# total IOU 80.56755119187206
# Total Matches 152
# Precision 0.3510392609699769
# Recall 0.8786127167630058
# Number of Boxes for 1st 173
# Authors of 1st ['16737']
# Labels of 1st {'Police Officer': 110, 'Civilian': 57, 'First Person POV': 6}
# Actions of 1st: {'Unable to tell': 166, 'Unable to determine': 142, "Can't tell": 87, 'Lying on ground': 77, 'Standing': 74, 'Male': 31, 'Uniform': 29, 'Sitting/Kneeling/Crouching on ground': 10, 'White': 7, 'Holding person': 5, 'Has firearm': 3, 'Walking away': 3, 'Entering door/building': 3, 'Kneeling on person': 3, 'Wrestling/Grappling': 3, 'Drawing a weapon': 2}
# Number of Boxes for 2nd 433
# Authors of 2nd ['16725', '16735']
# Labels of 2st {'Police Officer': 307, 'Civilian': 98, 'First Person POV': 17, 'Police Vehicle': 11}
# Actions of 2st: {'Male': 317, 'Uniform': 300, 'White': 236, 'Standing': 197, '': 173, 'Lying on ground': 130, 'Questioning/Talking to': 126, 'Sitting/Kneeling/Crouching on ground': 83, 'Injured': 79, 'Unable to tell': 68, 'Female': 50, 'Holding person': 47, 'Has firearm': 25, 'Unable to determine': 18, 'Walking towards': 12, 'Parked': 11, 'Drawing a weapon': 11, 'Frisking (search of a person)': 11, 'Reaching for weapon': 9, 'Black or African American': 6, 'Searching (search of place or space)': 3, 'Exiting door/building': 3, 'Walking away': 2, 'Entering door/building': 2, 'Exiting a vehicle': 1, 'Putting on PPE (e.g. gloves)': 1, 'Leaving scene': 1}
#
# Video # 40
# FN:  13
# FP:  171
# TN:  60
# avg IOU 0.5979127987976414
# total IOU 50.822587897799515
# Total Matches 85
# Precision 0.33203125
# Recall 0.8673469387755102
# Number of Boxes for 1st 98
# Authors of 1st ['16736']
# Labels of 1st {'Police Officer': 40, 'Civilian': 37, 'Police Vehicle': 13, 'First Person POV': 8}
# Actions of 1st: {'': 118, 'Uniform': 40, 'Standing': 34, 'Lying on ground': 17, 'Injured': 17, 'Male': 17, 'Holding person': 14, 'Parked': 13, 'Unable to tell': 12, 'Black or African American': 11, 'Walking away': 10, 'Unable to determine': 9, 'White': 8, 'Handcuffing': 6, 'Sitting/Kneeling/Crouching on ground': 4, 'Female': 3, 'Entering police vehicle': 2, 'Exiting a vehicle': 1, 'Walking towards': 1}
# Number of Boxes for 2nd 256
# Authors of 2nd ['16733']
# Labels of 2st {'Civilian': 125, 'First Person POV': 55, 'Police Vehicle': 40, 'Police Officer': 36}
# Actions of 2st: {'Black or African American': 127, 'Female': 96, 'Male': 93, 'Questioning/Talking to': 65, 'Standing': 62, "Can't tell": 52, 'White': 48, 'Injured': 47, 'Unable to tell': 41, 'Parked': 40, 'Uniform': 36, 'Walking away': 30, 'Holding person': 29, 'Unable to determine': 27, 'Lying on ground': 23, 'Walking towards': 22, 'Handcuffing': 19, 'Raising hands': 15, 'Sitting/Kneeling/Crouching on ground': 10, 'Mentally Distressed/Confused': 8, 'Pulling away': 6, 'Sitting': 2, 'Exiting a vehicle': 2, '': 2, 'Yelling/Gesticulating': 2}
#
# Video # 41
# FN:  2
# FP:  73
# TN:  17
# avg IOU 0.5655699282980416
# total IOU 117.07297515769461
# Total Matches 207
# Precision 0.7392857142857143
# Recall 0.9904306220095693
# Number of Boxes for 1st 209
# Authors of 1st ['16736']
# Labels of 1st {'Civilian': 111, 'First Person POV': 74, 'Police Officer': 16, 'Police Vehicle': 8}
# Actions of 1st: {'': 276, 'Black or African American': 81, 'Sitting/Kneeling/Crouching on ground': 77, 'Unable to determine': 62, 'Holding person': 56, 'Injured': 55, 'Male': 38, 'Unable to tell': 17, 'Putting on PPE (e.g. gloves)': 17, 'Standing': 16, 'Uniform': 12, 'Parked': 8, 'Handcuffing': 6, 'Mentally Distressed/Confused': 5, 'Questioning/Talking to': 5, "Can't tell": 4, 'Drawing a weapon': 3, 'Lying on ground': 3, 'Being placed into a police vehicle': 3, 'White': 2, 'Exiting a vehicle': 1}
# Number of Boxes for 2nd 280
# Authors of 2nd ['16730']
# Labels of 2st {'Civilian': 124, 'First Person POV': 115, 'Police Officer': 24, 'Police Vehicle': 17}
# Actions of 2st: {'Male': 238, 'Unable to tell': 144, 'Questioning/Talking to': 136, 'Black or African American': 117, "Can't tell": 115, 'Injured': 112, 'Holding person': 87, 'Being placed into a police vehicle': 52, 'Placing into police vehicle': 39, 'Walking towards': 27, 'Putting on PPE (e.g. gloves)': 26, 'Unable to determine': 23, 'Uniform': 23, 'Handcuffing': 23, 'Standing': 21, 'Wrestling/Grappling': 21, 'Mentally Distressed/Confused': 19, 'Sitting': 17, 'Parked': 17, 'Wrestling/grappling': 12, 'Pulling away': 12, 'Has firearm': 10, 'Drawing a weapon': 10, '': 6, 'Sitting/Kneeling/Crouching on ground': 5, 'Entering door/building': 5, 'Entering a police vehicle': 5, 'Lying on ground': 4, 'Showing aggression': 3, 'Exiting a vehicle': 1, 'Shoving/pushing': 1}
#
# Video # 42
# FN:  228
# FP:  136
# TN:  83
# avg IOU 0.5433431126663025
# total IOU 53.247625041297646
# Total Matches 98
# Precision 0.4188034188034188
# Recall 0.3006134969325153
# Number of Boxes for 1st 326
# Authors of 1st ['16730']
# Labels of 1st {'Police Officer': 306, 'Civilian': 16, 'First Person POV': 4}
# Actions of 1st: {'Unable to tell': 306, 'Unable to determine': 273, 'Standing': 270, "Can't tell": 207, 'Searching (search of a place or space)': 133, 'Uniform': 98, 'Male': 53, 'Walking away': 38, 'White': 19, 'Sitting/Kneeling/Crouching on ground': 6, 'Civilian Clothing': 5, 'Running towards': 3, 'Has firearm': 3, 'Walking towards': 2, 'Black or African American': 1, 'Kneeling on': 1}
# Number of Boxes for 2nd 234
# Authors of 2nd ['16731', '0', '16735']
# Labels of 2st {'First Person POV': 106, 'Police Officer': 74, 'Civilian': 26, 'Police Vehicle': 4}
# Actions of 2st: {'Unable to tell': 205, 'Unable to determine': 200, 'Standing': 112, "Can't tell": 109, 'Uniform': 84, 'Searching (search of a place or space)': 48, 'Walking away': 38, 'Walking towards': 33, 'Leaving scene': 26, 'Running towards': 22, 'Lying on ground': 21, 'Male': 19, 'Holding person': 15, 'Handcuffing': 15, 'White': 14, 'Parked': 12, 'Lights flashing': 12, '': 9, 'Questioning/Talking to': 7, 'Sitting/Kneeling/Crouching on ground': 1}
#
# Vid2 43 - no annotations
#
# Video # 44
# FN:  48
# FP:  257
# TN:  27
# avg IOU 0.6839176101211971
# total IOU 268.09570316750927
# Total Matches 392
# Precision 0.6040061633281972
# Recall 0.8909090909090909
# Number of Boxes for 1st 440
# Authors of 1st ['0', '16734']
# Labels of 1st {'Police Officer': 375, 'Civilian': 18}
# Actions of 1st: {'': 399, 'Uniform': 369, 'Male': 354, 'Standing': 329, 'Searching (search of a place or space)': 151, 'Unable to tell': 81, 'Sitting/Kneeling/Crouching on ground': 61, 'Female': 52, 'Black or African American': 36, 'Yelling/Gesticulating': 28, 'Entering door/building': 8, 'Two or more': 6, 'Unable to determine': 3, 'Lying on ground': 2, 'Injured': 2}
# Number of Boxes for 2nd 649
# Authors of 2nd ['16730']
# Labels of 2st {'Police Officer': 498, 'First Person POV': 82, 'Civilian': 57, 'Police Vehicle': 12}
# Actions of 2st: {'Uniform': 414, 'Standing': 403, 'Male': 379, 'Unable to tell': 284, 'Unable to determine': 221, 'White': 187, "Can't tell": 145, 'Walking away': 107, 'Asian': 107, 'Sitting/Kneeling/Crouching on ground': 68, 'Searching (search of place or space)': 59, 'Black or African American': 38, 'Walking towards': 35, 'Female': 35, 'Questioning/Talking to': 26, 'Holding person': 24, 'Civilian Clothing': 22, 'Native Hawaiian or Other Pacific Islander': 16, 'Frisking (search of a person)': 12, 'Yelling/Gesticulating': 12, 'Parked': 12, 'Lights flashing': 12, 'Entering door/building': 8, 'Searching (search of a place or space)': 7, 'Two or more': 5, 'Lying on ground': 4, 'Wrestling/Grappling': 3, 'Other': 1, '': 1, 'Kneeling on person': 1}
#
# Video # 45
# FN:  210
# FP:  6
# TN:  240
# avg IOU 0.5906997006330512
# total IOU 58.479270362672075
# Total Matches 99
# Precision 0.9428571428571428
# Recall 0.32038834951456313
# Number of Boxes for 1st 309
# Authors of 1st ['16731', '0']
# Labels of 1st {'Police Officer': 241, 'First Person POV': 40, 'Civilian': 24}
# Actions of 1st: {'Standing': 249, 'Uniform': 241, 'Unable to tell': 215, 'Male': 209, 'Has firearm': 134, 'White': 90, 'Unable to determine': 73, "Can't tell": 40, 'Walking away': 30, 'Entering door/building': 24, 'Lying on ground': 24, 'Injured': 24, 'Mentally Distressed/Confused': 24, 'Female': 23, 'Has taser': 14, '': 12, 'Drawing a weapon': 5, 'Exiting a vehicle': 3, 'Yelling/Gesticulating': 3}
# Number of Boxes for 2nd 105
# Authors of 2nd ['0', '16736']
# Labels of 2st {'Police Officer': 74, 'First Person POV': 30}
# Actions of 2st: {'Has firearm': 105, 'Male': 89, 'White': 75, 'Civilian Clothing': 42, 'Standing': 35, 'Walking away': 34, 'Uniform': 33, 'Unable to tell': 26, 'Civilian clothing': 25, 'Unable to determine': 13, 'Has taser': 11, 'Exiting door/building': 10, 'Reaching for weapon': 6, 'Drawing a weapon': 5, "Can't tell": 5, '': 4, 'Yelling/Gesticulating': 4, 'Female': 3}
# No match for video 46
#
# {'Police Officer': 2604, 'First Person POV': 70, 'Civilian': 1226, 'Police Vehicle': 129, 'Ambulance': 379, 'Bystander': 113, '': 16}
#
# {'Male': 17867, 'Uniform': 16119, 'Standing': 15837, 'Unable to tell': 12418, '': 9926, 'White': 9123, 'Unable to determine': 7806, "Can't tell": 4448, 'Has firearm': 4246, 'Black or African American': 4099, 'Holding person': 3637, 'Sitting/Kneeling/Crouching on ground': 3579, 'Female': 2986, 'Lying on ground': 2965, 'Questioning/Talking to': 2456, 'Injured': 2057, 'Walking away': 1754, 'Parked': 1546, 'Civilian Clothing': 1311, 'Drawing a weapon': 1216, 'Walking towards': 1141, 'Searching (search of a place or space)': 643, 'Lights flashing': 587, 'Holstering a weapon': 534, 'Handcuffing': 500, 'Has taser': 487, 'Hispanic or Latino': 446, 'Wrestling/Grappling': 412, 'Entering door/building': 345, 'Running towards': 284, 'Searching vehicle': 258, 'Putting on PPE (e.g. gloves)': 233, 'Leaving scene': 226, 'Yelling/Gesticulating': 205, 'Mentally Distressed/Confused': 162, 'Kneeling on': 156, 'Kneeling on person': 150, 'Running away': 150, 'Sitting': 141, 'Frisking (search of a person)': 136, 'Exiting a vehicle': 127, 'Asian': 110, 'Searching (search of place or space)': 102, 'Frisking (search of person)': 95, 'Reaching for weapon': 91, 'Pulling away': 90, 'Native Hawaiian or Other Pacific Islander': 86, 'Placing into police vehicle': 77, 'Moving': 65, 'Raising hands': 62, 'Other': 58, 'Exiting door/building': 56, 'Being placed into a police vehicle': 55, 'Reaching for license': 54, 'Wrestling/grappling': 50, 'Searching a vehicle': 44, 'Showing aggression': 42, 'Civilian clothing': 37, 'Intoxicated': 31, 'Entering a police vehicle': 26, 'Defending (self)': 23, 'Exiting vehicle': 17, 'Has knife': 16, 'Two or more': 14, 'Knocking': 12, 'Shoving/pushing': 11, 'Reaching license': 10, 'Defending (someone else)': 7, 'Entering police vehicle': 6, 'Homeless': 4, 'Throwing': 3, 'Knocking down door': 2, 'Reloading firearm': 1}

# %%
def download_all_objects_in_folder(folder):
    s3_resource = boto3.resource('s3', aws_access_key_id = 'AKIA3ANFA5T5VQOTVQGV', 
              aws_secret_access_key= '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')
    my_bucket = s3_resource.Bucket('copa-bwc')
    objects = my_bucket.objects.filter(Prefix=folder)
    for obj in objects:
        path, filename = os.path.split(obj.key)
        my_bucket.download_file(obj.key, filename)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def get_labels(labelAttrs):
  labels = []
  for i in labelAttrs:
    if type(i['value']) is list:
      for value in i['value']:    
        labels.append(value)
    else:
      labels.append(i['value']) 
  return ', '.join(labels)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
def display_video(index, file1, file2):
  images_array = []

  vid1 = file1[index]
  frame_list = vid1['data']['image_url']
  for i in range(len(file2)):
    if file2[i]['data']['image_url'] == frame_list:
      vid2 = file2[i] #if there is no match the program breaks here
      break

  for i in range(len(frame_list)):
    frame_list[i] = frame_list[i].split('/')[1]

  vid1_dict = {}
  for i in vid1['result']['data']:
    if i['frame'] in vid1_dict:
      vid1_dict[i['frame']].append(i)
    else:
      vid1_dict[i['frame']] = [i] 

  vid2_dict = {}
  for i in vid2['result']['data']:
    if i['frame'] in vid2_dict:
      vid2_dict[i['frame']].append(i)
    else:
      vid2_dict[i['frame']] = [i]

  for i in range(len(frame_list)):
    if i in vid1_dict:
      num1 = len(vid1_dict[i])
    else:
      num1 = 0 
    if i in vid2_dict:
      num2 = len(vid2_dict[i])
    else:
      num2 = 0
    print(i, num1, num2)
    im = Image.open(frame_list[i])
    draw = ImageDraw.Draw(im)
    if num1 == 0 and num2 == 0:
      pass
    elif num2 ==0: 
      for j in range(len(vid1_dict[i])):
        draw.rectangle([(vid1_dict[i][j]['coordinate'][0]['x'], 
                         vid1_dict[i][j]['coordinate'][0]['y']),
                        (vid1_dict[i][j]['coordinate'][2]['x'], 
                         vid1_dict[i][j]['coordinate'][2]['y'])],
                       outline='red')
        draw.text([vid1_dict[i][j]['coordinate'][0]['x'], 
                   vid1_dict[i][j]['coordinate'][0]['y']], 
                  get_labels(vid1_dict[i][j]['labelAttrs']))
    elif num1 ==0:
      for j in range(len(vid2_dict[i])):
        draw.rectangle([(vid2_dict[i][j]['coordinate'][0]['x'], 
                         vid2_dict[i][j]['coordinate'][0]['y']),
                        (vid2_dict[i][j]['coordinate'][2]['x'], 
                         vid2_dict[i][j]['coordinate'][2]['y'])],
                       outline='blue')
        draw.text([vid2_dict[i][j]['coordinate'][0]['x'], 
                   vid2_dict[i][j]['coordinate'][0]['y']], 
                  get_labels(vid2_dict[i][j]['labelAttrs']))
    else:
      for j in range(len(vid1_dict[i])):
        draw.rectangle([(vid1_dict[i][j]['coordinate'][0]['x'], 
                         vid1_dict[i][j]['coordinate'][0]['y']),
                        (vid1_dict[i][j]['coordinate'][2]['x'], 
                         vid1_dict[i][j]['coordinate'][2]['y'])],
                       outline='red')
        draw.text([vid1_dict[i][j]['coordinate'][0]['x'], 
                   vid1_dict[i][j]['coordinate'][0]['y']], 
                  get_labels(vid1_dict[i][j]['labelAttrs']))
        

      for j in range(len(vid2_dict[i])):
        draw.rectangle([(vid2_dict[i][j]['coordinate'][0]['x'], 
                         vid2_dict[i][j]['coordinate'][0]['y']),
                        (vid2_dict[i][j]['coordinate'][2]['x'], 
                         vid2_dict[i][j]['coordinate'][2]['y'])],
                       outline='blue')
        draw.text([vid2_dict[i][j]['coordinate'][0]['x'], 
                   vid2_dict[i][j]['coordinate'][0]['y']], 
                  get_labels(vid2_dict[i][j]['labelAttrs']))
    im.save(frame_list[i])
    images_array.append(im)
  #ipyplot.plot_images(images_array, max_images=len(frame_list), img_width=150)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Input the index of the video looking to download into the directory address

# %%
directory = file1[31]['data']['image_url'][0].split('/')[0]
download_all_objects_in_folder(directory)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Input the video index into the function call at the bottom of the block.

# %%
from PIL import Image, ImageDraw
filepath1 = '4-11 Results.json'
filepath2 = 'mar30_execute.json'

vid1 = {}
vid2 = {}

with open(filepath1) as f:
    file1 = json.load(f)

with open(filepath2) as f:
    file2 = json.load(f)

display_video(31, file1, file2)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# 0 1 1
# 1 1 1
# 2 1 0
# 3 1 1
# 4 1 1
# 5 1 1
# 6 1 1
# 7 1 1
# 8 1 1
# 9 1 1
# 10 1 1
# 11 1 1
# 12 1 1
# 13 1 1
# 14 0 1
# 15 0 1
# 16 0 1
# 17 0 1
# 18 0 1
# 19 0 1
# 20 0 0
# 21 0 0
# 22 0 0
# 23 1 1
# 24 1 1
# 25 1 0
# 26 0 0
# 27 0 0
# 28 0 0
# 29 0 0
# 30 0 0
# 31 0 0
# 32 0 0
# 33 0 0
# 34 0 0
# 35 0 0
# 36 0 0
# 37 0 0
# 38 1 1
# 39 1 1
# 40 1 1
# 41 1 1
# 42 1 1
# 43 1 1
# 44 1 1
# 45 1 1
# 46 1 1
# 47 1 1
# 48 1 1
# 49 1 1
# 50 1 1
# 51 1 1
# 52 1 0
# 53 1 0
# 54 1 1
# 55 1 1
# 56 1 1
# 57 1 2
# 58 1 2
# 59 1 2
# 60 1 0
# 61 2 2
# 62 2 2
# 63 2 2
# 64 2 2
# 65 2 2
# 66 2 2
# 67 2 2
# 68 2 2
# 69 2 2
# 70 2 2
# 71 2 2
# 72 2 2
# 73 2 2
# 74 2 2
# 75 2 2
# 76 2 2
# 77 2 2
# 78 2 2
# 79 2 2
# 80 2 2
# 81 2 2
# 82 0 1
# 83 0 1
# 84 0 1
# 85 0 1
# 86 0 1
# 87 0 1
# 88 0 1
# 89 0 1
# 90 0 1
# 91 0 0
# 92 0 0
# 93 0 0
# 94 0 0
# 95 0 0
# 96 0 0
# 97 0 0
# 98 0 0
# 99 0 0
# 100 0 0
# 101 0 0
# 102 0 0
# 103 0 0
# 104 0 1
# 105 0 0
# 106 0 1
# 107 0 1
# 108 0 1
# 109 0 1
# 110 0 1
# 111 0 1
# 112 0 1
# 113 0 1
# 114 0 1
# 115 0 0
# 116 0 0
# 117 0 0
# 118 0 0
# 119 0 0
# 120 0 0
# 121 0 0
# 122 0 0
# 123 0 0
# 124 0 0
# 125 0 0
# 126 1 1
# 127 1 1
# 128 1 1
# 129 1 1
# 130 1 1
# 131 1 1
# 132 1 1
# 133 1 2
# 134 1 1
# 135 1 1
# 136 1 1
# 137 1 1
# 138 1 1
# 139 1 1
# 140 1 1
# 141 1 1
# 142 1 1
# 143 1 1
# 144 1 1
# 145 1 1
# 146 1 1
# 147 1 1
# 148 1 1
# 149 1 1
# 150 1 1
# 151 1 1
# 152 1 1
# 153 1 1
# 154 1 1
# 155 1 1
# 156 1 1
# 157 1 1
# 158 1 1
# 159 1 1
# 160 1 1
# 161 1 1
# 162 1 1
# 163 1 1
# 164 1 1
# 165 1 1
# 166 1 1
# 167 1 1
# 168 1 1
# 169 1 1
# 170 1 1
# 171 1 1
# 172 1 1
# 173 1 1
# 174 1 1
# 175 1 1
# 176 1 1
# 177 1 1
# 178 1 1
# 179 1 1
# 180 1 1
# 181 1 1
# 182 1 1
# 183 1 1
# 184 1 0
# 185 1 0
# 186 1 0
# 187 1 0
# 188 1 0
# 189 1 0
# 190 0 0
# 191 0 0
# 192 0 0
# 193 0 0
# 194 0 0
# 195 0 0
# 196 0 0
# 197 0 0
# 198 0 0
# 199 0 0
# 200 0 0
# 201 0 0
# 202 0 0
# 203 0 0
# 204 0 0
# 205 0 0
# 206 0 0
# 207 0 0
# 208 0 1
# 209 2 2
# 210 2 2
# 211 2 2
# 212 2 2
# 213 2 2
# 214 2 2
# 215 2 2
# 216 2 2
# 217 2 2
# 218 2 2
# 219 2 2
# 220 2 2
# 221 2 2
# 222 2 3
# 223 2 2
# 224 2 2
# 225 1 2
# 226 1 2
# 227 1 2
# 228 1 2
# 229 1 2
# 230 1 2
# 231 1 2
# 232 1 1
# 233 1 1
# 234 1 1
# 235 1 1
# 236 1 1
# 237 1 1
# 238 1 1
# 239 1 2
# 240 1 4
# 241 0 2
# 242 0 1
# 243 0 3
# 244 0 4
# 245 1 4
# 246 1 2
# 247 1 1
# 248 1 1
# 249 1 1
# 250 1 1
# 251 1 1
# 252 1 1
# 253 1 1
# 254 1 1
# 255 1 1
# 256 1 1
# 257 1 0
# 258 2 1
# 259 1 1
# 260 1 1
# 261 1 2
# 262 1 3
# 263 1 3
# 264 1 3
# 265 1 4
# 266 0 4
# 267 0 4
# 268 0 3
# 269 0 2
# 270 0 3
# 271 0 3
# 272 0 3
# 273 0 2
# 274 0 4
# 275 0 3
# 276 0 3
# 277 0 2
# 278 0 2
# 279 1 2
# 280 2 2
# 281 2 2
# 282 2 2
# 283 2 2
# 284 2 2
# 285 2 2
# 286 2 2
# 287 2 2
# 288 2 2
# 289 2 2
# 290 2 2
# 291 2 2
# 292 2 2
# 293 2 2
# 294 2 2
# 295 2 2
# 296 2 2
# 297 2 2
# 298 2 2
# 299 2 2
# 300 2 4
# 301 4 4
# 302 1 4
# 303 0 3
# 304 0 3
# 305 0 3
# 306 0 4
# 307 5 4
# 308 5 4
# 309 5 4
# 310 5 4
# 311 5 4
# 312 5 4
# 313 5 4
# 314 5 3
# 315 5 3
# 316 5 3
# 317 5 4
# 318 5 4
# 319 5 4
# 320 6 4
# 321 6 5
# 322 6 5
# 323 6 5
# 324 6 5
# 325 6 5
# 326 6 6
# 327 6 6
# 328 6 6
# 329 6 6
# 330 6 6
# 331 6 6
# 332 6 6
# 333 6 6
# 334 6 6
# 335 6 6
# 336 6 6
# 337 6 6
# 338 6 6
# 339 2 5
# 340 2 2
# 341 3 0
# 342 3 0
# 343 3 0
# 344 1 0
# 345 0 0
# 346 1 0
# 347 0 1
# 348 0 1
# 349 0 1
# 350 0 3
# 351 0 3
# 352 0 3
# 353 0 3
# 354 0 3
# 355 0 3
# 356 0 3
# 357 0 3
# 358 0 3
# 359 0 0
# 360 0 0
# 361 0 0
# 362 0 1
# 363 0 0
# 364 0 1
# 365 0 1
# 366 0 1
# 367 0 2
# 368 0 1
# 369 0 1
# 370 0 3
# 371 0 3
# 372 0 3
# 373 0 2
# 374 0 2
# 375 0 0
# 376 0 0
# 377 0 0
# 378 0 0
# 379 0 0
# 380 0 0
# 381 0 0
# 382 0 0
# 383 0 0
# 384 0 0
# 385 0 0
# 386 0 0
# 387 0 0
# 388 0 0
# 389 0 0
# 390 0 0
# 391 0 0
# 392 0 0
# 393 0 0
# 394 0 0
# 395 0 0
# 396 0 0
# 397 0 0
# 398 0 0
# 399 0 0
# 400 0 0
# 401 0 0
# 402 0 0
# 403 0 0
# 404 1 0
# 405 1 0
# 406 1 1
# 407 1 1
# 408 1 1
# 409 0 1
# 410 1 1
# 411 2 1
# 412 2 1
# 413 3 1
# 414 2 1
# 415 2 1
# 416 2 1
# 417 2 1
# 418 2 1
# 419 2 1
# 420 2 1
# 421 3 1
# 422 3 1
# 423 2 1
# 424 2 1
# 425 2 1
# 426 2 1
# 427 2 1
# 428 2 1
# 429 2 1
# 430 2 1
# 431 2 1
# 432 2 1
# 433 2 1
# 434 3 1
# 435 3 0
# 436 3 1
# 437 3 2
# 438 3 2
# 439 3 1
# 440 3 2
# 441 3 2
# 442 3 2
# 443 3 2
# 444 3 2
# 445 3 2
# 446 3 2
# 447 1 2
# 448 3 2
# 449 3 2
# 450 3 2
# 451 3 3
# 452 3 3
# 453 3 0
# 454 3 0
# 455 3 0
# 456 3 0
# 457 3 0
# 458 3 1
# 459 3 1
# 460 2 1
# 461 2 1
# 462 2 1
# 463 3 2
# 464 3 2
# 465 2 0
# 466 2 1
# 467 1 1
# 468 2 1
# 469 2 1
# 470 2 1
# 471 2 1
# 472 2 2
# 473 3 2
# 474 1 2
# 475 4 2
# 476 4 2
# 477 4 2
# 478 3 2
# 479 3 2
# 480 3 2
# 481 1 2
# 482 1 2
# 483 3 2
# 484 2 2
# 485 2 1
# 486 2 2
# 487 2 2
# 488 2 2
# 489 2 2
# 490 3 2
# 491 3 2
# 492 3 2
# 493 3 2
# 494 2 2
# 495 2 2
# 496 2 2
# 497 2 2
# 498 3 2
# 499 1 1
# 500 1 1
# 501 2 2
# 502 2 2
# 503 2 1
# 504 2 1
# 505 2 1
# 506 2 1
# 507 2 1
# 508 1 0
# 509 3 0
# 510 3 0
# 511 2 0
# 512 1 0
# 513 0 0
# 514 1 0
# 515 0 0
# 516 1 0
# 517 1 0
# 518 1 0
# 519 1 0
# 520 1 0
# 521 1 0
# 522 1 0
# 523 1 0
# 524 1 0
# 525 1 0
# 526 0 0
# 527 0 0
# 528 0 0
# 529 0 0

# %% [markdown]
# Find the first 4 digits of the address and create a folder for the video downloaded. Most are 'Log_' so no need to change anything except the address for the target folder.

# %%
for i in os.listdir():
  if i[0:4] == 'Log_':
    shutil.move(i, "Video 31/"+i)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
